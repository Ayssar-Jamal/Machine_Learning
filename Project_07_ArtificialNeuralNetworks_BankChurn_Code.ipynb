# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Blue' > **Project 6 - Artificial Neural Networks (ANN):**
# <left> <font size=5 style='font-family:Courier New' color='Green' > **Bank Churn**

# %% [markdown]
# <left> <font size=6 style='font-family:Courier New' color='Orange' > **Objective:**
# <br> <left> <font size=3 style='font-family:Courier New' color='Black'>
# Predicting whether a Bank Customer will leave or not in the next 6 Months...

# %% [markdown]
# <left> <font size=6 style='font-family:Courier New' color='Orange' > **Data Dictionary:**
# <br> <left> <font size=3 style='font-family:Courier New' color='Black'> **CustomerId**: Unique ID which is assigned to each customer.
# <br> <left> <font size=3 style='font-family:Courier New' color='Black'> **Surname**: Last name of the customer.
# <br> <left> <font size=3 style='font-family:Courier New' color='Black'> **CreditScore**: It defines the credit history of the customer.
# <br> <left> <font size=3 style='font-family:Courier New' color='Black'> **Geography**: A customer’s location.
# <br> <left> <font size=3 style='font-family:Courier New' color='Black'> **Gender**: It defines the Gender of the customer.
# <br> <left> <font size=3 style='font-family:Courier New' color='Black'> **Age**: Age of the customer.
# <br> <left> <font size=3 style='font-family:Courier New' color='Black'> **Tenure**: Number of years for which the customer has been with the bank.
# <br> <left> <font size=3 style='font-family:Courier New' color='Black'> **NumOfProducts**: It refers to the number of products that a customer has purchased through the bank.
# <br> <left> <font size=3 style='font-family:Courier New' color='Black'> **Balance**: Account balance.
# <br> <left> <font size=3 style='font-family:Courier New' color='Black'> **HasCrCard**: It is a categorical variable that decides whether the customer has a credit card or not.
# <br> <left> <font size=3 style='font-family:Courier New' color='Black'> **EstimatedSalary**: Estimated salary.
# <br> <left> <font size=3 style='font-family:Courier New' color='Black'> **isActiveMember**: It is a categorical variable that decides whether the customer is an active member of the bank or not ( Active member in the sense, using bank products regularly, making transactions, etc).
# <br> <left> <font size=3 style='font-family:Courier New' color='Black'> **Exited**: It is a categorical variable that decides whether the customer left the bank within six months or not. It can take two values
# <br> <left> <font size=3 style='font-family:Courier New' color='Black'>$\;\;$ **-** 0: No; Customer did not leave the bank.
# <br> <left> <font size=3 style='font-family:Courier New' color='Black'>$\;\;$ **-** 1: Yes; Customer left the bank.

# %% [markdown]
# <left> <font size=6 style='font-family:Courier New' color='Orange' > **Case Understanding:**
# <br> <left> <font size=3 style='font-family:Courier New' color='Black'> It's quite clear and straightforward case study with small No. of Features. It's all about how to avoid losing customers to competitors.
# <br> <left> <font size=3 style='font-family:Courier New' color='Black'> While the main object is to find the features that influence the Customers decision to either stay with bank or leave it, we've to go through all the features and analyze it in a manner to understand which of them has such impacts.
# <br> <left> <font size=3 style='font-family:Courier New' color='Black'> Due to database's nature, some features are expected to be unique or adding no value. On the other hand, some of them might be important and help us in deriving trends and draw conclusions to interpret such customers behaviour.
# <br> <left> <font size=3 style='font-family:Courier New' color='Black'> As a Data Scientist, knowing a trend is not the whole story! We will use this trend to recommend the Business Owner about what he must do to increase the loyalty of his current Customers, as well as add new ones.

# %% [markdown]
# <left> <font size=6 style='font-family:Courier New' color='Orange' > **1. Prework:**

# %%
# Intallation of Imbalance Learn Librariy:
# !pip install imblearn --user
# !pip install imbalanced-learn --user

# Data Reading and Manipulating:
import numpy as np 
import pandas as pd 

# Statistical Functions:
import scipy.stats as stats

# Data Visualization:
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline
sns.set()

# Splitting and s Validation:
from sklearn.model_selection import (train_test_split , KFold , StratifiedKFold , cross_val_score ,
                                     GridSearchCV , RandomizedSearchCV)
# Imputation:
from sklearn.impute import (SimpleImputer , KNNImputer)

# Over-Sampling and Under-Sampling:
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler

# Preprocessing:
from sklearn.preprocessing import (FunctionTransformer , LabelEncoder , OneHotEncoder , KBinsDiscretizer)

# Elbow Curve and Silhouette Score Visualization:
#!pip install yellowbrick
#from yellowbrick.cluster import (ElbowVisualizer , SilhouetteVisualizer)

# Scaling:
from sklearn.preprocessing import (StandardScaler , MinMaxScaler)

# Pipeline:
from sklearn.pipeline import Pipeline, make_pipeline

# Distance Computation:
from scipy.spatial.distance import cdist , pdist

# Transformation:
from sklearn.compose import ColumnTransformer

# Clustering:
from sklearn.cluster import KMeans , AgglomerativeClustering

# Regularization:
from sklearn.linear_model import Ridge , Lasso

# Logistic Regression:
from sklearn.linear_model import LogisticRegression

# Decision Tree:
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier

# Classifiers:
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier 
from sklearn.ensemble import (BaggingClassifier  , RandomForestClassifier ,
                              AdaBoostClassifier , GradientBoostingClassifier , StackingClassifier)
# !pip install xgboost
from xgboost import XGBClassifier 

# Performance Metrics:
from sklearn.metrics import silhouette_score
from scipy.cluster.hierarchy import cophenet , dendrogram , linkage

# Regressors:
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import (BaggingRegressor , RandomForestRegressor , 
                              AdaBoostRegressor , GradientBoostingRegressor , StackingRegressor)
from xgboost import XGBRegressor

# Performance Metrics:
from sklearn import metrics
from sklearn.metrics import (f1_score , accuracy_score , recall_score , precision_score , confusion_matrix , 
                             roc_auc_score , precision_recall_curve , roc_curve , classification_report , r2_score , 
                             mean_squared_error , mean_absolute_error)

# Expanding of Display: 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 200)
pd.set_option('mode.chained_assignment', None)

# Suppressing Version Warnings:
import warnings
warnings.filterwarnings("ignore")

# Grid Settings:
sns.set_style(style = 'darkgrid')

# Code Structuring:
# !pip install nb-black 

# Calculate Execution Time:
import time

# Tensorflow and Keras:
import tensorflow as tf
import keras
from keras import (callbacks , initializers , regularizers)
from tensorflow.keras import backend
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import (ModelCheckpoint , ReduceLROnPlateau)
from tensorflow.keras import (losses , backend , optimizers , Sequential)
from tensorflow.keras.layers import (Dense , Input , Dropout , BatchNormalization)
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.models import Sequential

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1:** Code Output has been cleared to avoid annoyed Project Presentation.

# %%
# Loading the csv file and assign it to a variable dataset:

dataset = pd.read_csv('Project_07_ArtificialNeuralNetworks_BankChurn_Dataset.csv')

# %%
# Creating a Copy of the Dataset:

df = dataset.copy()

# %% [markdown]
# <left> <font size=6 style='font-family:Courier New' color='Orange' > **2. Sanity Check:**

# %%
# Ensuring that everything is working as expected by displaying the First 5 Data Rows:

df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
# Ensuring that everything is working as expected by displaying the Last 5 Data Rows:

df.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %%
# Examining the No. of Data Rows and Features:

print('\033[0m', '\033[92m' , 'Dataset contains ' , 
      '\033[1m', '\033[91m' , '{:,}'.format(df.shape[0]) , 
      '\033[0m', '\033[92m' , ' Data Rows and ' , 
      '\033[1m', '\033[91m' , df.shape[1] , 
      '\033[0m', '\033[92m' , ' Features.' , sep='')
# Out:
# Dataset contains 10,000 Data Rows and 14 Features.

# %%
# Examining the Dataset Information and Data Types:

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
# Displayinh the No. of Non-Null/Null/Zero Entries in the Columns:

def summary(x):
    column = x.columns.values.tolist()
    dtype = [x[i].dtypes for i in x.columns]
    non_null = [x[i].notnull().sum() for i in column]
    null = [x[i].isnull().sum() for i in column]
    zero = [x[i].eq(0).sum() for i in column]
    summary_df = pd.DataFrame(data = {'Column Name' : column ,
                                      'Column Type' : dtype ,
                                      'Non-Null Entries' : non_null , 
                                      'Null Entries' : null , 
                                      'Zero Entries' : zero})
    return summary_df

summary(df)
# Out:
#         Column Name Column Type  Non-Null Entries  Null Entries  Zero Entries
# 0         RowNumber       int64             10000             0             0
# 1        CustomerId       int64             10000             0             0
# 2           Surname      object             10000             0             0
# 3       CreditScore       int64             10000             0             0
# 4         Geography      object             10000             0             0
# 5            Gender      object             10000             0             0
# 6               Age       int64             10000             0             0
# 7            Tenure       int64             10000             0           413
# 8           Balance     float64             10000             0          3617
# 9     NumOfProducts       int64             10000             0             0
# 10        HasCrCard       int64             10000             0          2945
# ...

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1:** Dataset contains 10,000 Data Rows and 14 Features.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2:** Out of 14 Features, 9 have 'int64' Data Type, 2 have 'float64' Data Type, and 3 have 'object' Data Type.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **3:** No Missing 'NaN' Values have been found, all Data Rows have been filled with entries.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **4:** 5 Features have Zero Entries - Will be investigated.

# %%
# Examiningthe Dataset against duplicate Data Rows:

dup = df.duplicated().sum()
print('\033[0m', '\033[92m' , 'There are ' , 
      '\033[1m', '\033[91m' , dup , 
      '\033[0m', '\033[92m' , ' Duplicate Data Rows in the Dataset.' , sep='')
# Out:
# There are 0 Duplicate Data Rows in the Dataset.

# %%
# Checking the No. of Unique Values in each Columns:

for i in df.columns:
    print('\033[0m' , '\033[92m' , 'No. of Unique Values (' , 
          '\033[0m' , '\033[91m' , i ,  
          '\033[0m' , '\033[92m' , '): ' , 
          '\033[1m' , '\033[92m' , '{:,}'.format(df[i].nunique()) , sep='')

print('\033[1m' , '\033[94m' , '\n- - - Output Ends Here! - - -' , sep = '')
# Out:
# No. of Unique Values (RowNumber): 10,000
# No. of Unique Values (CustomerId): 10,000
# No. of Unique Values (Surname): 2,932
# No. of Unique Values (CreditScore): 460
# No. of Unique Values (Geography): 3
# No. of Unique Values (Gender): 2
# No. of Unique Values (Age): 70
# No. of Unique Values (Tenure): 11
# No. of Unique Values (Balance): 6,382
# No. of Unique Values (NumOfProducts): 4
# No. of Unique Values (HasCrCard): 2
# No. of Unique Values (IsActiveMember): 2
# No. of Unique Values (EstimatedSalary): 9,999
# No. of Unique Values (Exited): 2
#
# - - - Output Ends Here! - - -

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1:** No duplicate Customers have been found.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2:** Since the No. of Unique Values in both 'RowNumber' and 'CustomerId' Features is equal to the No. of Total Data Rows, then such Features add no value to our analysis and can be removed safely.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **3:** Although 'Surname' Features show a possibility of common Family Names among Customers, such possibility is not helpful and will result in huge No. of Encoded Categories if 'Surname' Feature is kept.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **4:** Overall, the remaining Features looks realistic and will be investigated more in upcoming Analysis.

# %%
# Defining Lists to segregate the Datasey into Discrete and Continuous Features:

discrete_var = ['Geography' , 'Gender' , 'Tenure' , 'NumOfProducts' , 'HasCrCard' , 'IsActiveMember' , 'Exited'] 
continuous_var = ['CreditScore' , 'Age' , 'Balance' , 'EstimatedSalary']

# %%
# Investigate the values inside some Important columns which - by sense - shall have specific Categories/Reasonable Ranges:

for i in discrete_var:
    print('\033[1m' , '\033[92m' , i , 
          '\033[0m' , '\033[92m' , ': ' ,
          '\033[1m' , '\033[91m' , df[i].value_counts().count() ,
          ' ' ,
          '\033[0m' , '\033[92m' , 'Unique Values' ,  sep = '')
    print('\033[0m' , '\033[92m' , df[i].value_counts() , sep = '')
    
    if discrete_var.index(i) == len(discrete_var)-1:
        print('\033[1m' , '\033[94m' , '\n- - - Output Ends Here! - - -' , sep = '')
        break
        
    print("-"*40)
# Out:
# Geography: 3 Unique Values
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64
# ----------------------------------------
# Gender: 2 Unique Values
# Male      5457
# Female    4543
# Name: Gender, dtype: int64
# ----------------------------------------
# Tenure: 11 Unique Values
# 2     1048
# 1     1035
# 7     1028
# 8     1025
# 5     1012
# 3     1009
# 4      989
# 9      984
# 6      967
# 10     490
# 0      413
# Name: Tenure, dtype: int64
# ----------------------------------------
# NumOfProducts: 4 Unique Values
# 1    5084
# 2    4590
# 3     266
# 4      60
# Name: NumOfProducts, dtype: int64
# ----------------------------------------
# HasCrCard: 2 Unique Values
# 1    7055
# 0    2945
# Name: HasCrCard, dtype: int64
# ----------------------------------------
# IsActiveMember: 2 Unique Values
# 1    5151
# 0    4849
# Name: IsActiveMember, dtype: int64
# ----------------------------------------
# Exited: 2 Unique Values
# 0    7963
# ...

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1:** No abnomaly values have been detected in any feature, all values look realistic.

# %%
# Verifying the statistics of the String Features:

df.describe(include='object').T
# Out:
#            count unique     top  freq
# Surname    10000   2932   Smith    32
# Geography  10000      3  France  5014
# Gender     10000      2    Male  5457

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1:** 2,932 Unique 'Surname' have been found; while many Customers would hold the same Family Name, Smith is the most frequent with 32 Customers.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2:** 3 Unique 'Geography' have been found; while many Customers would live in the same Country, France is the most frequent with 5,014 Customers.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **3:** 2 Unique 'Gender' have been found; while Customers are divided into Male and Female, Male is the most frequent with 5,457 Customers.

# %%
# Verifying the statistics of the Numeric Features:

df.describe().T.apply(lambda s: s.apply('{0:.3f}'.format))
# Out:
#                      count          mean        std           min  \
# RowNumber        10000.000      5000.500   2886.896         1.000
# CustomerId       10000.000  15690940.569  71936.186  15565701.000
# CreditScore      10000.000       650.529     96.653       350.000
# Age              10000.000        38.922     10.488        18.000
# Tenure           10000.000         5.013      2.892         0.000
# Balance          10000.000     76485.889  62397.405         0.000
# NumOfProducts    10000.000         1.530      0.582         1.000
# HasCrCard        10000.000         0.706      0.456         0.000
# IsActiveMember   10000.000         0.515      0.500         0.000
# EstimatedSalary  10000.000    100090.240  57510.493        11.580
# Exited           10000.000         0.204      0.403         0.000
#
#                           25%           50%           75%           max
# RowNumber            2500.750      5000.500      7500.250     10000.000
# ...

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.1:** Both 'RowNumber' and 'CustomerId' represent Unique Identifiers that add no value and must be removed accordingly.
#
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2.1:** 'CreditScore' varies between 350 and 850 with a Mean of 650.529.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2.2:** 'CreditScore' Distribution is Left Skewed with some Extreme Values beyond the Left Whisker.
#
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **3.1:** 'Age' varies between 18 and 92 with a Mean of 38.922 $\approx$ 39 ('Age' is a Whole Number, not Real Number).
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **3.2:** 75% of Customers have a maximum of 44 Years of Age.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **3.3:** 'Age' Distribution is Right Skewed with some Extreme Values beyond the Right Whisker.
#
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **4.1:** 'Tenure' varies between 0 and 10 with a Mean of 5.013 $\approx$ 5 ('Tenure' is a Whole Number, not Real Number).
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **4.2:** 75% of Customers have a maximum of 7 Years of relationship with the Bank.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **4.3:** 'Tenure' Distribution is neither Skewed nor has Extreme Values.
#
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **5.1:** 'Balance' varies between 0 and 250,898.090 with a Mean of 76,485.889.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **5.2:** 75% of Customers have a maximum of 127,644.240 Balance.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **5.3:** 'Balance' Distribution is Right Skewed with no Extreme Values.
#
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **6.1:** 'NumOfProducts' varies between 1 and 4 with a Mean of 1.530 $\approx$ 2 ('NumOfProducts' is a Whole Number, not Real Number).
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **6.2:** 75% of Customers have a maximum of 2 Products.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **6.3:** 'NumOfProducts' Distribution is Right Skewed with some Extreme Values beyond the Right Whisker.
#
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **7.1:** 'HasCrCard' has 2 possible values (0 or 1).
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **7.2:** Around 75% of Customers have a Credit Card.
#
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **8.1:** 'IsActiveMember' has 2 possible values (0 or 1).
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **8.2:** Around 75% of Customers are Active Members.
#
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **9.1:** 'EstimatedSalary' varies between 11.580 and 199,992.480 with a Mean of 100,090.240.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **9.2:** Around 25% of Customers have a maximum Salary of 51,002.110.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **9.3:** 'EstimatedSalary' Distribution is neither Skewed nor has Extreme Values.
#
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **10.1:** 'Exited' has 2 possible values (0 or 1).
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **10.2:** Around 25% of Customers have left the Bank.

# %% [markdown]
# <left> <font size=6 style='font-family:Courier New' color='Orange' > **3. Data Preprocessing:**

# %%
# Dropping the RowNumber Feature:

df.drop(['RowNumber'] , axis = 1 , inplace=True)

# %%
# Dropping the CustomerId Feature:

df.drop(['CustomerId'] , axis = 1 , inplace=True)

# %%
# Dropping the Surname Feature:

df.drop(['Surname'] , axis = 1 , inplace=True)

# %%
# Ensuring that everything is working as expected after dropping the RowNumber and CustomerId Features by displaying the first 5 Data Rows:

df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
# Changing the Data Type of Text Features from Object to Category for better Memory Utilization:

columns_object = df.select_dtypes(['object'])

columns_object.columns
for i in columns_object.columns:
    df[i] = df[i].astype('category')

# %%
# Ensuring that everything is working as expected after changing the dType of Object Features:

summary(df)
# Out:
#         Column Name Column Type  Non-Null Entries  Null Entries  Zero Entries
# 0       CreditScore       int64             10000             0             0
# 1         Geography    category             10000             0             0
# 2            Gender    category             10000             0             0
# 3               Age       int64             10000             0             0
# 4            Tenure       int64             10000             0           413
# 5           Balance     float64             10000             0          3617
# 6     NumOfProducts       int64             10000             0             0
# 7         HasCrCard       int64             10000             0          2945
# 8    IsActiveMember       int64             10000             0          4849
# 9   EstimatedSalary     float64             10000             0             0
# 10           Exited       int64             10000             0          7963

# %% [markdown]
# <left> <font size=6 style='font-family:Courier New' color='Orange' > **4. Univariate Analysis:**

# %%
# Checking the Distribution of Discrete Features:

for index, element in enumerate(discrete_var):
    print('\033[0m' , '\033[92m' , 'Count Plot: ' , 
          '\033[1m' , '\033[91m' , element , 
          '\033[0m' , '\033[92m' , sep='')

    total = float(len(df))
    plt.figure(figsize=(15 , 4))
    #count = df[element].value_counts()
    #percentage = df[element].value_counts(normalize=True)
    #frame = pd.DataFrame({'Count': count, 'Percentage': percentage})    
   # print(frame)

    print(df[element].value_counts().sort_values(ascending=False))
    plot = sns.countplot(data=df , x = element , color = 'yellow', 
                         order=df[element].value_counts(ascending=True).index)

    for p in plot.patches:
        percentage = '{:.2f}%'.format(100 * p.get_height()/total)
        x = p.get_x() + p.get_width()/2
        y = p.get_height() * 0.5
        plot.annotate(percentage , (x, y) , ha='center' , va='center' , size=11 , color='darkgreen')

    #plot.xticks(rotation = 90)
    plot.set(xlabel=None)
    plot.xaxis.label.set_color('olive')
    plot.tick_params(axis='x', colors='olive')
    plot.set(ylabel='Frequency')
    plot.yaxis.label.set_color('olive')
    plot.tick_params(axis='y', colors='olive')
    plt.show();

    if index == len(discrete_var)-1:
        print('\033[1m' , '\033[94m' , '\n- - - Output Ends Here! - - -' , sep = '')
        break
        
    print('\033[0m' , '\033[92m' , "-"*120 , sep='')
# Out:
# Count Plot: Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64
# ------------------------------------------------------------------------------------------------------------------------
# Count Plot: Gender
# Male      5457
# Female    4543
# Name: Gender, dtype: int64
# ------------------------------------------------------------------------------------------------------------------------
# Count Plot: Tenure
# 2     1048
# 1     1035
# 7     1028
# 8     1025
# 5     1012
# 3     1009
# 4      989
# 9      984
# 6      967
# 10     490
# 0      413
# Name: Tenure, dtype: int64
# ------------------------------------------------------------------------------------------------------------------------
# Count Plot: NumOfProducts
# 1    5084
# 2    4590
# 3     266
# 4      60
# Name: NumOfProducts, dtype: int64
# ------------------------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ##### <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <left> <font size=4 style='font-family:Courier New' color='Grey'> **1. Geography:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.1** The Bank's Customers are concentrated in three countries; Spain, Germany, and France.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.2.** 50.14% of Bank's Customers live in France. Such observation, may indicate that the Bank is originally established in France with some international branches.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.3** Similar percentages of Bank's Customers live in both Spain and Germany with 24.77% and 25.09% respectively.
#
# <left> <font size=4 style='font-family:Courier New' color='Grey'> **2. Gender:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2.** Similar percentages of Bank's Customers in term of Gender is observed with 45.43% and 54.57 for both Females and Males respectively.
#
# <left> <font size=4 style='font-family:Courier New' color='Grey'> **3. Tenure:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **3.1** The Bank's Customers have a Tenure between 0 Year (New Customers) and 10 Years (Loyal Customers). Such observation, may indicate that the Bank has been established 10 Years back.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **3.2** 90.97% of Customers have a Tenure between 1 and 9 Years.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **3.3** Both the New Customers and the Oldest Customers represent the smallest portion of Customers Base with 9.03%.
#
# <left> <font size=4 style='font-family:Courier New' color='Grey'> **4. NumOfProducts:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **4.1** The Bank's Customers have a No. of Product varies between 1 Product and 4 Products. Such observation, may indicate that the Bank has to launch more various Products.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **4.2** 96.74% of Customers have either 1 or 2 Products.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **4.3** Slight Portion of Bank's Customers have either 1 or 4 Products with a Percentage of 3.26%.
#
# <left> <font size=4 style='font-family:Courier New' color='Grey'> **5. HasCrCard:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **5.1** While 70.55% of Bank's Customers own a Credit Card, 29.45% of them do not. Such observation, may indicate a marketing failure as the Credit Cards are One of the necessities of life; Furthermore, in the common sence any Bank's Customer must own it.
#
# <left> <font size=4 style='font-family:Courier New' color='Grey'> **6. IsActiveMember:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **6.1** While 51.51% of Bank's Customers are actives, 48.49% of them are not. Such observation, may raise a Risk Flag due to the inactivity of half of Customers.
#
# <left> <font size=4 style='font-family:Courier New' color='Grey'> **7. Exited:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **7.1** While 79.63% of Bank's Customers are loyal and did not leave the Bank, 20.37% of them have left it. Such observation, may raise a Risk Flag due to the huge percentage of Exiting (One Fifth of Customers is neither normal behaviour nor small percentage).

# %%
# Checking the Distribution of 1st Continuous Features:

i = 0

print('\033[0m' , '\033[92m' , 'Multi Plots: ' , 
  '\033[1m' , '\033[91m' , continuous_var[i] , 
  '\033[0m' , '\033[92m' , sep='')

print('\n' , df[[continuous_var[i]]].describe().T.apply(lambda s: s.apply('{0:.1f}'.format)) , sep='')

fig, axis = plt.subplots(1 , 2 , figsize=(15 , 4))
   
sns.boxplot(data=df , x=continuous_var[i] , ax=axis[0] , color='Lime')
plt.setp(axis[0] , xlabel='')
plt.setp(axis[0] , ylabel='')
    
sns.histplot(data=df , x=continuous_var[i] , ax=axis[1] , color='deepskyblue' , stat='density')
sns.kdeplot(data=df , x=continuous_var[i] , ax=axis[1] , color='orangered')
plt.setp(axis[1] , xlabel='')
plt.setp(axis[1] , ylabel='')
i = index
fig.tight_layout(pad=2.0)
# Out:
# Multi Plots: CreditScore
#
#                count   mean   std    min    25%    50%    75%    max
# CreditScore  10000.0  650.5  96.7  350.0  584.0  652.0  718.0  850.0

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** The Bank's Customers have a Credit Score varies between 350 (Minimum) and 850 (Maximum) with a Mean of 650.5.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2.** Although of Left Skewness of Credit Score, Values look realistic and Outliers can be accepted without processing.

# %%
# Checking the Distribution of 2nd Continuous Features:

i = 1

print('\033[0m' , '\033[92m' , 'Multi Plots: ' , 
  '\033[1m' , '\033[91m' , continuous_var[i] , 
  '\033[0m' , '\033[92m' , sep='')

print('\n' , df[[continuous_var[i]]].describe().T.apply(lambda s: s.apply('{0:.1f}'.format)) , sep='')

fig, axis = plt.subplots(1 , 2 , figsize=(15 , 4))
   
sns.boxplot(data=df , x=continuous_var[i] , ax=axis[0] , color='Lime')
plt.setp(axis[0] , xlabel='')
plt.setp(axis[0] , ylabel='')
    
sns.histplot(data=df , x=continuous_var[i] , ax=axis[1] , color='deepskyblue' , stat='density')
sns.kdeplot(data=df , x=continuous_var[i] , ax=axis[1] , color='orangered')
plt.setp(axis[1] , xlabel='')
plt.setp(axis[1] , ylabel='')
i = index
fig.tight_layout(pad=2.0)
# Out:
# Multi Plots: Age
#
#        count  mean   std   min   25%   50%   75%   max
# Age  10000.0  38.9  10.5  18.0  32.0  37.0  44.0  92.0

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** The Bank's Customers have an Age varies between 18 (Minimum) and 92 (Maximum) with a Mean of 38.9.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2.** Although of Right Skewness of Age, Values look realistic and Outliers can be accepted without processing - Older Customrs represent retirees.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **3.** Around 96% of Customers have a maximum age of 62 Years, which indicate - most likely - the working (Non-Retired) category.

# %%
# Checking the Distribution of 3rd Continuous Features:

i = 2

print('\033[0m' , '\033[92m' , 'Multi Plots: ' , 
  '\033[1m' , '\033[91m' , continuous_var[i] , 
  '\033[0m' , '\033[92m' , sep='')

print('\n' , df[[continuous_var[i]]].describe().T.apply(lambda s: s.apply('{0:.1f}'.format)) , sep='')

fig, axis = plt.subplots(1 , 2 , figsize=(15 , 4))
   
sns.boxplot(data=df , x=continuous_var[i] , ax=axis[0] , color='Lime')
plt.setp(axis[0] , xlabel='')
plt.setp(axis[0] , ylabel='')
    
sns.histplot(data=df , x=continuous_var[i] , ax=axis[1] , color='deepskyblue' , stat='density')
sns.kdeplot(data=df , x=continuous_var[i] , ax=axis[1] , color='orangered')
plt.setp(axis[1] , xlabel='')
plt.setp(axis[1] , ylabel='')
i = index
fig.tight_layout(pad=2.0)
# Out:
# Multi Plots: Balance
#
#            count     mean      std  min  25%      50%       75%       max
# Balance  10000.0  76485.9  62397.4  0.0  0.0  97198.5  127644.2  250898.1

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** The Bank's Customers have a Balance varies between 0 (Minimum) and 250,898.1 (Maximum) with a Mean of 76,485.9.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2.** Although of Right Skewness of Balance, Values look realistic - It's quite normal to have such variation when talking abount Balance or Salary.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **3.** Around 36% of Customers have a Zero Balance, which indicate - most likely - Undergraduate Customers (Non-Working).

# %%
# Checking the Distribution of 4th Continuous Features:

i = 3

print('\033[0m' , '\033[92m' , 'Multi Plots: ' , 
  '\033[1m' , '\033[91m' , continuous_var[i] , 
  '\033[0m' , '\033[92m' , sep='')

print('\n' , df[[continuous_var[i]]].describe().T.apply(lambda s: s.apply('{0:.1f}'.format)) , sep='')

fig, axis = plt.subplots(1 , 2 , figsize=(15 , 4))
   
sns.boxplot(data=df , x=continuous_var[i] , ax=axis[0] , color='Lime')
plt.setp(axis[0] , xlabel='')
plt.setp(axis[0] , ylabel='')
    
sns.histplot(data=df , x=continuous_var[i] , ax=axis[1] , color='deepskyblue' , stat='density')
sns.kdeplot(data=df , x=continuous_var[i] , ax=axis[1] , color='orangered')
plt.setp(axis[1] , xlabel='')
plt.setp(axis[1] , ylabel='')
i = index
fig.tight_layout(pad=2.0)
# Out:
# Multi Plots: EstimatedSalary
#
#                    count      mean      std   min      25%       50%  \
# EstimatedSalary  10000.0  100090.2  57510.5  11.6  51002.1  100193.9
#
#                       75%       max
# EstimatedSalary  149388.2  199992.5

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** The Bank's Customers have an Estimated Salary varies between 11.6 (Minimum) and 199,992.5 (Maximum) with a Mean of 100,090.2 .
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2.** Customers with very low salary might represent Undergraduate Customers especially when knowing that young customers with an Age below 22 Years are existed in the Dataset.

# %% [markdown]
# <left> <font size=6 style='font-family:Courier New' color='Orange' > **5. Bivariate Analysis:**

# %%
# Discovering the Correlation between the Numeric Features:

print('\033[1m' , '\033[92m' , 'Correlation Table:' , sep='')

df.corr()
# Out:
# Correlation Table:
#                  CreditScore       Age    Tenure   Balance  NumOfProducts  \
# CreditScore         1.000000 -0.003965  0.000842  0.006268       0.012238
# Age                -0.003965  1.000000 -0.009997  0.028308      -0.030680
# Tenure              0.000842 -0.009997  1.000000 -0.012254       0.013444
# Balance             0.006268  0.028308 -0.012254  1.000000      -0.304180
# NumOfProducts       0.012238 -0.030680  0.013444 -0.304180       1.000000
# HasCrCard          -0.005458 -0.011721  0.022583 -0.014858       0.003183
# IsActiveMember      0.025651  0.085472 -0.028362 -0.010084       0.009612
# EstimatedSalary    -0.001384 -0.007201  0.007784  0.012797       0.014204
# Exited             -0.027094  0.285323 -0.014001  0.118533      -0.047820
#
#                  HasCrCard  IsActiveMember  EstimatedSalary    Exited
# CreditScore      -0.005458        0.025651        -0.001384 -0.027094
# ...

# %%
# Plotting the Correlation between the Numeric Features:

print('\033[1m' , '\033[92m' , 'Correlation Plot:' , sep='')

plt.figure(figsize=(10, 10))
mask = np.triu(np.ones_like(df.corr()))
sns.heatmap(df.corr(), cmap="viridis", annot=True, mask=mask);
# Out:
# Correlation Plot:

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **5.1 Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** Except of a Weak Positive Correlation between Age and Exited (+ 0.29) and a Weak Negative Correlation between Balance and NumOfProducts (-0.30), all remaining Features show a type of independency with no significant or worthy correlations.

# %%
# Defining a Function to plot Discrete Featues vs Target Feature:

def stacked_barplot(data, predictor, target):
    count = data[predictor].nunique()
    sorter = data[target].value_counts().index[-1]
    tab1 = pd.crosstab(data[predictor], data[target], margins=True) \
                      .sort_values(by=sorter, ascending=False)

    print('\033[0m' , '\033[92m' , 'Stacked Bar Plot: ' , 
      '\033[1m' , '\033[91m' , predictor , 
      '\033[0m' , '\033[92m' , ' vs ' ,
      '\033[1m' , '\033[91m' , target , 
      '\033[0m' , '\033[92m' , sep='')    

    print(tab1)
    tab = pd.crosstab(data[predictor], data[target], normalize='index') \
                .sort_values(by=sorter, ascending=False)
    tab.plot(kind='bar', stacked=True, color = ('Lime','yellow'), figsize=(count + 5, 4))
    plt.legend(loc='lower left', frameon=False)
    plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
    plt.xlabel('')
    plt.show()

# %%
# Checking the Distribution of 1st Discrete Featues vs Target Feature:

stacked_barplot(df , discrete_var[0], discrete_var[-1])
# Out:
# Stacked Bar Plot: Geography vs Exited
# Exited        0     1    All
# Geography
# All        7963  2037  10000
# Germany    1695   814   2509
# France     4204   810   5014
# Spain      2064   413   2477

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** Although Spain Customers show the most loyalty, both Germany and France Customers show more tend to leave the Bank.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2.** Whereas Both Germany and France Customers have similar No. of leavers, around One Third of Germany Customers have left the Bank!

# %%
# Checking the Distribution of 2nd Discrete Featues vs Target Feature:

stacked_barplot(df , discrete_var[1], discrete_var[-1])
# Out:
# Stacked Bar Plot: Gender vs Exited
# Exited     0     1    All
# Gender
# All     7963  2037  10000
# Female  3404  1139   4543
# Male    4559   898   5457

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** Although Male Customers are more represented than Females, around Quarter of Female Customers have left the Bank!

# %%
# Checking the Distribution of 3rd Discrete Featues vs Target Feature:

stacked_barplot(df , discrete_var[2], discrete_var[-1])
# Out:
# Stacked Bar Plot: Tenure vs Exited
# Exited     0     1    All
# Tenure
# All     7963  2037  10000
# 1        803   232   1035
# 3        796   213   1009
# 9        771   213    984
# 5        803   209   1012
# 4        786   203    989
# 2        847   201   1048
# 8        828   197   1025
# 6        771   196    967
# 7        851   177   1028
# 10       389   101    490
# 0        318    95    413

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** No clear relationship or significant trend is observed between Tenure and Leaving's Behaviour.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2.** Leaving's Percentage varies between around 20% (Tenure: 1 to 10) to around 25% (Tenure: 0).

# %%
# Checking the Distribution of 4th Discrete Featues vs Target Feature:

stacked_barplot(df , discrete_var[3], discrete_var[-1])
# Out:
# Stacked Bar Plot: NumOfProducts vs Exited
# Exited            0     1    All
# NumOfProducts
# All            7963  2037  10000
# 1              3675  1409   5084
# 2              4242   348   4590
# 3                46   220    266
# 4                 0    60     60

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** Customers with 2 Products show the most loyalty with the least percentage of Leaving (Around 8%).
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2.** Customers with 1, 3, or 4 Products show massive Percentages of Leaving (Around 21.6%, 83%, and 100% respectively).

# %%
# Checking the Distribution of 5th Discrete Featues vs Target Feature:

stacked_barplot(df , discrete_var[4], discrete_var[-1])
# Out:
# Stacked Bar Plot: HasCrCard vs Exited
# Exited        0     1    All
# HasCrCard
# All        7963  2037  10000
# 1          5631  1424   7055
# 0          2332   613   2945

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** Although Customers who have Credit Cards show higher No. of leavers, Both Customers who either have a Credit Card or who don't have it, show a similar percentages of leaving with 20%.

# %%
# Checking the Distribution of 6th Discrete Featues vs Target Feature:

stacked_barplot(df , discrete_var[5], discrete_var[-1])
# Out:
# Stacked Bar Plot: IsActiveMember vs Exited
# Exited             0     1    All
# IsActiveMember
# All             7963  2037  10000
# 0               3547  1302   4849
# 1               4416   735   5151

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** Customers who are active have more tend to leave the Bank (around 27%) than customers who are inactive (around 14%).

# %%
# Defining a Function to plot Continuous Featues vs Target Feature:

def continuous_plot(x , y):
    print('\033[0m' , '\033[92m' , 'Box Plot: ' , 
          '\033[1m' , '\033[91m' , x , 
          '\033[0m' , '\033[92m' , ' vs ' ,
          '\033[1m' , '\033[91m' , y , 
          '\033[0m' , '\033[92m' , sep='') 
        
    values = df[y].unique().tolist()
    
    for value in values:
        mean = round(np.mean(df[df[y]==value][x]) , 2)
        print('\033[0m' , '\033[92m' , 'Class ' , 
              '\033[1m' , '\033[91m' , value , 
              '\033[0m' , '\033[92m' , ' Mean = ' ,
              '\033[0m' , '\033[92m' , f"{mean:,}" , 
              '\033[0m' , '\033[92m' , sep='')

    sns.catplot(data=df , x=y , y=x , kind='box' , ci=False , height=4 , \
                showfliers=False , color = 'Lime')
    plt.show();

# %%
# Checking the Distribution of 1st Continuous Featues vs Target Feature:

continuous_plot(continuous_var[0] , discrete_var[-1])
# Out:
# Box Plot: CreditScore vs Exited
# Class 1 Mean = 645.35
# Class 0 Mean = 651.85

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** No clear relationship can be observed between Credit Score and Leaving's Behaviour!

# %%
# Checking the Distribution of 1st Continuous Featues (Using the Intervals) vs Target Feature:

df['CreditScore_int'] = pd.cut(df['CreditScore'] , 5)

stacked_barplot(df , 'CreditScore_int', discrete_var[-1])

df.drop(['CreditScore_int'] , axis = 1 , inplace=True)
# Out:
# Stacked Bar Plot: CreditScore_int vs Exited
# Exited              0     1    All
# CreditScore_int
# All              7963  2037  10000
# (550.0, 650.0]   2627   689   3316
# (650.0, 750.0]   2798   667   3465
# (750.0, 850.0]   1285   313   1598
# (450.0, 550.0]   1125   307   1432
# (349.5, 450.0]    128    61    189

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** Although of their small representation, Customers with lower Credit Score (350 - 450) tend to leave the Bank more than others with higher Credit Scores (Around one third of them have left the Bank).

# %%
# Checking the Distribution of 2nd Continuous Featues vs Target Feature:

continuous_plot(continuous_var[1] , discrete_var[-1])
# Out:
# Box Plot: Age vs Exited
# Class 1 Mean = 44.84
# Class 0 Mean = 37.41

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** Customers with higher Age tend to leave the Bank more than other younger customers.

# %%
# Checking the Distribution of 3rd Continuous Featues vs Target Feature:

continuous_plot(continuous_var[2] , discrete_var[-1])
# Out:
# Box Plot: Balance vs Exited
# Class 1 Mean = 91,108.54
# Class 0 Mean = 72,745.3

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** Customers with higher Balance tend to leave the Bank more than others.

# %%
# Checking the Distribution of 4th Continuous Featues vs Target Feature:

continuous_plot(continuous_var[3] , discrete_var[-1])
# Out:
# Box Plot: EstimatedSalary vs Exited
# Class 1 Mean = 101,465.68
# Class 0 Mean = 99,738.39

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** No clear relationship can be observed between EstimatedSalary and Leaving's Behaviour!

# %%
# Checking the Distribution of 4th Continuous Featues (Using the Intervals) vs Target Feature:

df['EstimatedSalary_int'] = pd.cut(df['EstimatedSalary'] , 5)

stacked_barplot(df , 'EstimatedSalary_int', discrete_var[-1])

df.drop(['EstimatedSalary_int'] , axis = 1 , inplace=True)
# Out:
# Stacked Bar Plot: EstimatedSalary_int vs Exited
# Exited                    0     1    All
# EstimatedSalary_int
# All                    7963  2037  10000
# (159996.3, 199992.48]  1563   431   1994
# (80003.94, 120000.12]  1622   407   2029
# (40007.76, 80003.94]   1630   403   2033
# (120000.12, 159996.3]  1587   402   1989
# (-188.401, 40007.76]   1561   394   1955

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** All Customers whatever their Estimated Salary show a convergent tend in leaving the Bank.

# %%
# Defining a Function to investigate possible relationships/Correlations:

def multi_plot(x , y):
    print('\033[0m' , '\033[92m' , 'Box Plot: ' , 
          '\033[1m' , '\033[91m' , x , 
          '\033[0m' , '\033[92m' , ' vs ' ,
          '\033[1m' , '\033[91m' , y , 
          '\033[0m' , '\033[92m' , sep='') 
    
    values = df[x].unique().tolist()
    for value in values:
        mean = round(np.mean(df[df[x]==value][y]) , 2) 
        print('\033[0m' , '\033[92m' , 'Category ' , 
              '\033[1m' , '\033[91m' , value , 
              '\033[0m' , '\033[92m' , ' Mean = ' ,
              '\033[0m' , '\033[92m' , f"{mean:,}" , 
              '\033[0m' , '\033[92m' , sep='')
    
    sns.catplot(data=df , x=x , y=y , kind='box' , ci=False , height=5, aspect=3 , \
                showfliers=False , color='Lime')
    plt.show();

# %%
multi_plot(x = 'NumOfProducts' , y = 'CreditScore')
# Out:
# Box Plot: NumOfProducts vs CreditScore
# Category 1 Mean = 649.12
# Category 3 Mean = 648.11
# Category 2 Mean = 652.19
# Category 4 Mean = 653.58

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** No clear relationship can be observed between NumOfProducts and CreditScorer!

# %%
multi_plot(x = 'Gender' , y = 'CreditScore')
# Out:
# Box Plot: Gender vs CreditScore
# Category Female Mean = 650.83
# Category Male Mean = 650.28

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** Both Male and Female Customers have similar Credit Scores.

# %%
multi_plot(x = 'Geography' , y = 'CreditScore')
# Out:
# Box Plot: Geography vs CreditScore
# Category France Mean = 649.67
# Category Spain Mean = 651.33
# Category Germany Mean = 651.45

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** Customers have similar Credit Scores whatever their Country of Origin.

# %%
multi_plot(x = 'NumOfProducts' , y = 'Age')
# Out:
# Box Plot: NumOfProducts vs Age
# Category 1 Mean = 39.67
# Category 3 Mean = 43.2
# Category 2 Mean = 37.75
# Category 4 Mean = 45.68

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** Older Customers tend to have more products than youngers.

# %%
multi_plot(x = 'Gender' , y = 'Age')
# Out:
# Box Plot: Gender vs Age
# Category Female Mean = 39.24
# Category Male Mean = 38.66

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** Both Male and Female Customers have similar Ages.

# %%
multi_plot(x = 'Geography' , y = 'Age')
# Out:
# Box Plot: Geography vs Age
# Category France Mean = 38.51
# Category Spain Mean = 38.89
# Category Germany Mean = 39.77

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** Customers have similar Ages whatever their Country of Origin.

# %%
multi_plot(x = 'NumOfProducts' , y = 'EstimatedSalary')
# Out:
# Box Plot: NumOfProducts vs EstimatedSalary
# Category 1 Mean = 99,487.26
# Category 3 Mean = 104,318.13
# Category 2 Mean = 100,452.01
# Category 4 Mean = 104,763.72

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** It's well observed that Estimated Salary has no effect on No. of Products.

# %%
multi_plot(x = 'Gender' , y = 'EstimatedSalary')
# Out:
# Box Plot: Gender vs EstimatedSalary
# Category Female Mean = 100,601.54
# Category Male Mean = 99,664.58

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** Both Male and Female Customers have similar Estimated Salaries.

# %%
multi_plot(x = 'Geography' , y = 'EstimatedSalary')
# Out:
# Box Plot: Geography vs EstimatedSalary
# Category France Mean = 99,899.18
# Category Spain Mean = 99,440.57
# Category Germany Mean = 101,113.44

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** Customers have similar Estimated Salaries whatever their Country of Origin.

# %%
multi_plot(x = 'NumOfProducts' , y = 'Balance')
# Out:
# Box Plot: NumOfProducts vs Balance
# Category 1 Mean = 98,551.87
# Category 3 Mean = 75,458.33
# Category 2 Mean = 51,879.15
# Category 4 Mean = 93,733.14

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** It's well observed that Balance has some effects on No. of Products where Customers with high Balances tend to have 1 or 4 Products.

# %%
multi_plot(x = 'Gender' , y = 'Balance')
# Out:
# Box Plot: Gender vs Balance
# Category Female Mean = 75,659.37
# Category Male Mean = 77,173.97

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** Both Male and Female Customers have similar Balances.

# %%
multi_plot(x = 'Geography' , y = 'Balance')
# Out:
# Box Plot: Geography vs Balance
# Category France Mean = 62,092.64
# Category Spain Mean = 61,818.15
# Category Germany Mean = 119,730.12

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** Customers who live in Germany have higher Average Balance than those who live in both France and Spain.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2.** Customers with either very low or very high Balances are found only in both France and Spain.

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='darkblue'> **Insights (EDA):**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> During the analysis, the focal point was the Exiting Behaviour.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> In order to be able to give our business recommendations and expectations about potential customers who show a high probability of Exiting, we were in a real need to determine the most important factors that have a positive influence on such behaviour.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> Consequently, we've the below insights which will constitute a solid base for our recommendations!
#
# <br> <left> <font size=4 style='font-family:Courier New' color='Grey'> **1. CreditScore:**
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **1.1** CreditScore is varying between 350 and 850 with a Mean of 650.529.
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **1.2** No Correlation is found between CreditScore and any other Feature within the Dataset.
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **1.3** Customers with lower CreditScore (350 - 450) tend to leave the Bank more than others with higher Credit Scores (Around one third of them left the Bank).
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **1.4** NumOfProducts, Gender, and Geography Features neither have no impact on CreditScore by increasing or decreasing it.
#
# <br> <left> <font size=4 style='font-family:Courier New' color='Grey'> **2. Geography:**
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **2.1** Customers are located in three countries; Spain, Germany, and France.
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **2.2** 50.14% of Customers lives in France. Such observation may indicate that the Bank is originally established in France with international branches in both of Germany and Spain.
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **2.3** Customers who live in Germany tend to leave the Bank more than those who live in France or Spain (Around one third of them left the Bank).
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **2.4** Customers have similar EstimatedSalary and Age (Averages) whatever their Country of Resident.
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **2.5** Customers who live in Germany have higher Balance than those who live in France or Spain.
#
# <br> <left> <font size=4 style='font-family:Courier New' color='Grey'> **3. Gender:**
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **3.1** The percentage of Male Customers is slightly higher than the percentage of Female Customers (54.57% to 45.53%).
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **3.2** Female Customers tend to leave the Bank more than Males (Around quarter of them left the Bank).
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **3.3** Both Male and Female Customers have similar CreditScore, Age, EstimatedSAlary, and Balance.
#
# <br> <left> <font size=4 style='font-family:Courier New' color='Grey'> **4. Age:**
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **4.1** Age is varying between 18 Years and 92 Years with a Mean of 39 Years approximately.
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **4.2** 75% of Customers has a maximum of 44 Years of Age. Such observation indicates that the vast majority of Customers are youth.
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **4.3** Weak Positive Correlation is found between Age and Exited Feature (+ 0.29).
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **4.4** Older Customers (higher Age) tend to leave the Bank more than younger Customers (Lower Age).
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **4.5** Younger Customers tend to own Products less than Older Customers.
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **4.6** Customers have similar Age (Average) whatever their Gender or Country of Resident.
#
# <br> <left> <font size=4 style='font-family:Courier New' color='Grey'> **5. Tenure:**
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **5.1** Tenure is varying between 0 Years and 10 Years with a Mean of 5 Years approximately. Such observation may indicate that the Bank has been established 10 Years back.
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **5.2** 90.97% of Customers has a Tenure between 1 and 9 Years.
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **5.3** No Correlation is found between CreditScore and any other Feature within the Dataset.
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **5.4** No clear relationship or significant trend is observed between Tenure and Exiting Behaviour.
#
# <br> <left> <font size=4 style='font-family:Courier New' color='Grey'> **6. Balance:**
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **6.1** Balance is varying between 0 and 250,898 with a Mean of 76,486 approximately.
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **6.2** Around 36% of Customers have a Zero Balance. Such observation may indicate - most likely - Undergraduate Customers (Non-Working).
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **6.3** Very Weak Positive Correlation is found between Balance and Exited Feature (+ 0.12).
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **6.4** Weak Negative Correlation is found between Balance and NumOfProducts Feature (- 0.30).
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **6.5** Customers who have higher Balance tend to leave the Bank more than those with lower Balance.
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **6.6** Customers with higher Balance prefer to own 1 or 4 Products.
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **6.7** Customers have similar Balance whatever their Gender.
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **6.8** Customers who live in Germany have higher Balance than those who live in France or Spain.
#
# <br> <left> <font size=4 style='font-family:Courier New' color='Grey'> **7. NumOfProducts:**
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **7.1** NumOfProducts is varying between 1 and 4 with a Mean of 2 approximately.
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **7.2** 96.74% of Customers has either 1 or 2 Products.
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **7.3** Weak Negative Correlation is found between NumOfProducts and Balance Feature (- 0.30).
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **7.4** Customers who own 3 or 4 Products tend to leave the Bank - significantly - more than those who own 1 or 2 Products (Customers who own 4 Products have completely gone!).
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **7.5** Customers have similar NumOfProducts whatever their CreditScore and EstimatedSalary.
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **7.6** Customers who own 1 or 2 Products are younger than those who own 3 or 4 Products.
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **7.7** Customers who own 2 Products have the lowest Balance, while those who own 1 Product have the highest Balance.
#
# <br> <left> <font size=4 style='font-family:Courier New' color='Grey'> **8. HasCrCard:**
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **8.1** The percentage of Customers who have Credit Card is slightly higher than the percentage of those who don't have (70.55% to 29.45%). Such observation, may indicate a marketing failure as the Credit Cards are One of the necessities of life - in the common sense - any Bank's Customer must own it.
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **8.2** No clear relationship or significant trend is observed between HasCrCard and Exiting Behaviour.
#
# <br> <left> <font size=4 style='font-family:Courier New' color='Grey'> **9. IsActiveMember:**
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **9.1** The percentage of Customers who are active is similar to the percentage of those who are not (51.51% to 48.49%). Such observation may raise a Risk Flag due to the inactivity of half of Customers.
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **9.2** Active Members tend to leave the Bank more than those who are Not Active.
#
# <br> <left> <font size=4 style='font-family:Courier New' color='Grey'> **10. EstimatedSalary:**
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **10.1** EstimatedSalary is varying between 11.580 and 199,992 with a Mean of 100,090.
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **10.2** Around 25% of Customers have a maximum Salary of 51,002.110.
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **10.3** No Correlation is found between EstimatedSalary and any other Feature within the Dataset.
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **10.4** No clear relationship or significant trend is observed between EstimatedSalary and Exiting Behaviour.
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **10.5** Customers have similar EstimatedSalary whatever the No. of Products they own, their Gender, or Country of Resident.
#
# <br> <left> <font size=4 style='font-family:Courier New' color='Grey'> **11. Exited:**
# <br> <left> <font size=4 style='font-family:Courier New' color='Black'> **11.1** While 79.63% of Bank's Customers are loyal and did not leave the Bank, 20.37% of them have left it. Such observation may raise a Risk Flag due to the huge percentage of Exiting (One Fifth of Customers is neither normal behaviour nor small percentage).

# %% [markdown]
# <left> <font size=6 style='font-family:Courier New' color='Orange' > **6. Neural Network Model:**

# %%
# Initially, we will crate a Copy of our Dataset to be used in Logistic Regression Model:

df_log = df.copy()

# %%
# Ensuring that the new Dataframe is working by displaying the first 5 Data Rows:

df_log.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
# Summarizing the No./Percentage of True (1) / False (0) Cases in Dataset:

target_var = discrete_var[-1]
    
print('\033[1m' , '\033[91m' , 'Dataset:' , '\033[0m' , sep='')
print('\033[92m' , 'Class 0 (False Cases): {0} ({1:0.2f}%)'. \
      format(len(df_log.loc[df_log[target_var] == 0]) , (len(df_log.loc[df_log[target_var]==0])/len(df_log.index)) * 100) , sep='')
print('\033[92m' , 'Class 1 (True Cases): {0} ({1:0.2f}%)'. \
      format(len(df_log.loc[df_log[target_var] == 1]) , (len(df_log.loc[df_log[target_var]==1])/len(df_log.index)) * 100) , sep='')
print()
# Out:
# Dataset:
# Class 0 (False Cases): 7963 (79.63%)
# Class 1 (True Cases): 2037 (20.37%)

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Red' > **Model Evaluation Criterion:**
# <br> <left> <font size=4 style='font-family:Courier New' color='red'> Neural Network Model can make Wrong Predictions if (Where **1: Left the Bank**; **0: Stay with Bank**):
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **-** Predict a Customer will leave the Bank but in fact he will not leave it (**FP**) - **Loss of Resources**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **-** Predict a Customer will not leave the Bank  but in fact he will leave it (**FN**) - **Loss of Opportunity**
#
# <br> <left> <font size=4 style='font-family:Courier New' color='red'> Which Loss is greater?
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> Since the process of improving the Bank Services will be conducted by the Bank Team, its result will impact all current customers whether they plan to stay or leave.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> Thus, Missed Classification a Customer as FP will cause a Loss of Time (Resources) which is already paid to improve the total services, while Missed Classification a Customer as FN will cause a Loss of Valuable Opportunity to keep the customer and avoiding losing him to competitors.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> Eventually, Reducing the **FN** by maximizing the **Recall** must be our Main Target.

# %%
# Splitting the Dataset into Independent and Dependent Subsets:

X = df_log.drop('Exited' , axis=1)
y = df_log.pop('Exited')

# %%
# Splitting the Dataset into Training, Validation, and Testing Subsets:

X_temp , X_test , y_temp , y_test = train_test_split(X , y , test_size = 0.2 , random_state = 1 , stratify=y , shuffle=True)
X_train , X_val , y_train , y_val = train_test_split(X_temp , y_temp , test_size = 0.2 , random_state = 1 , stratify=y_temp , shuffle=True)

# %%
# Summarizing the No./Percentage of True (1) / False (0) Classes in Training, Validation, and Testing Subsets:

print('\033[1m' , '\033[91m' , 'Dataset:' , '\033[0m' , sep='')
print('\033[0m' , '\033[92m' , 'Data Points: ' , '{:,}'.format(df.shape[0]) , '\033[0m' , sep='')
print('\033[92m' , 'Class 0 (False Cases): {0} ({1:0.2f}%)'. \
      format(len(df.loc[df[target_var] == 0]) , (len(df.loc[df[target_var]==0])/len(df.index)) * 100) , sep='')
print('\033[92m' , 'Class 1 (True Cases): {0} ({1:0.2f}%)'. \
      format(len(df.loc[df[target_var] == 1]) , (len(df.loc[df[target_var]==1])/len(df.index)) * 100) , sep='')

print('\033[0m' , '\033[92m' , '\n' , '-'*40 , '\n' , sep='')

print('\033[1m' , '\033[91m' , 'Training Subset:' , '\033[0m' , sep='')
print('\033[0m' , '\033[92m' , 'Data Points: ' , '{:,}'.format(y_train.shape[0]) , '\033[0m' , sep='')
print('\033[92m' , 'Class 0 (False Cases): {0} ({1:0.2f}%)'. \
      format(len(y_train[y_train[:]==0]) , (len(y_train[y_train[:]==0])/len(y_train)) * 100) , sep='')
print('\033[92m' , 'Class 1 (True Cases): {0} ({1:0.2f}%)'. \
      format(len(y_train[y_train[:]==1]) , (len(y_train[y_train[:]==1])/len(y_train)) * 100) , sep='')

print('\033[0m' , '\033[92m' , '\n' , '-'*40 , '\n' , sep='')

print('\033[1m' , '\033[91m' , 'Validation Subset:' , '\033[0m' , sep='')
print('\033[0m' , '\033[92m' , 'Data Points: ' , '{:,}'.format(y_val.shape[0]) , '\033[0m' , sep='')
print('\033[92m' , 'Class 0 (False Cases): {0} ({1:0.2f}%)'. \
      format(len(y_val[y_val[:]==0]) , (len(y_val[y_val[:]==0])/len(y_val)) * 100) , sep='')
print('\033[92m' , 'Class 1 (True Cases): {0} ({1:0.2f}%)'. \
      format(len(y_val[y_val[:]==1]) , (len(y_val[y_val[:]==1])/len(y_val)) * 100) , sep='')

print('\033[0m' , '\033[92m' , '\n' , '-'*40 , '\n' , sep='')

print('\033[1m' , '\033[91m' , 'Testing Subset:' , '\033[0m' , sep='')
print('\033[0m' , '\033[92m' , 'Data Points: ' , '{:,}'.format(y_test.shape[0]) , '\033[0m' , sep='')
print('\033[92m' , 'Class 0 (False Cases): {0} ({1:0.2f}%)'. \
      format(len(y_test[y_test[:]==0]) , (len(y_test[y_test[:]==0])/len(y_test)) * 100) , sep='')
print('\033[92m' , 'Class 1 (True Cases): {0} ({1:0.2f}%)'. \
      format(len(y_test[y_test[:]==1]) , (len(y_test[y_test[:]==1])/len(y_test)) * 100) , sep='')
# Out:
# Dataset:
# Data Points: 10,000
# Class 0 (False Cases): 7963 (79.63%)
# Class 1 (True Cases): 2037 (20.37%)
#
# ----------------------------------------
#
# Training Subset:
# Data Points: 6,400
# Class 0 (False Cases): 5096 (79.62%)
# Class 1 (True Cases): 1304 (20.38%)
#
# ----------------------------------------
#
# Validation Subset:
# Data Points: 1,600
# Class 0 (False Cases): 1274 (79.62%)
# Class 1 (True Cases): 326 (20.38%)
#
# ----------------------------------------
#
# Testing Subset:
# Data Points: 2,000
# Class 0 (False Cases): 1593 (79.65%)
# Class 1 (True Cases): 407 (20.35%)

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** Training, Validation, and Testing Subsets have been successfully created with similar Percentages of Minority Class (Class 1).

# %%
# One-Hot Encoding the Categorical Features in Training, Validation, and Testing Subsets:

X_train = pd.get_dummies(X_train , drop_first=True)
X_val = pd.get_dummies(X_val , drop_first=True)
X_test = pd.get_dummies(X_test , drop_first=True)

# %%
# Summarizing the Shapes of Training, Validation, and Testing Subsets:

print('\033[1m' , '\033[91m' , 'Dataset Shape:' , '\033[0m' , sep='')
print('\033[92m' , 'Data Points: ' , '{:,}'.format(df.shape[0]) , sep = '')
print('\033[92m' , 'Features: ' , df.shape[1] , sep = '')

print('\033[0m' , '\033[92m' , '\n' , '-'*25 , '\n' , sep='')

print('\033[1m' , '\033[91m' , 'X:' , '\033[0m' , sep='')
print('\033[92m' , 'Data Points: ' , '{:,}'.format(X.shape[0]) , sep = '')
print('\033[92m' , 'Features: ' , X.shape[1] , sep = '')
print()
print('\033[1m' , '\033[91m' , 'y:' , '\033[0m' , sep='')
print('\033[92m' , 'Data Points:' , '{:,}'.format(y.shape[0]) , sep = '')
print('\033[92m' , 'Features:' , '1' , sep = '')

print('\033[0m' , '\033[92m' , '\n' , '-'*25 , '\n' , sep='')

print('\033[1m' , '\033[91m' , 'X_train:' , '\033[0m' , sep='')
print('\033[92m' , 'Data Points :' , '{:,}'.format(X_train.shape[0]) , sep = '')
print('\033[92m' , 'Features: ' , X_train.shape[1] , sep = '')
print()
print('\033[1m' , '\033[91m' , 'y_train:' , '\033[0m' , sep='')
print('\033[92m' , 'Data Points :' , '{:,}'.format(y_train.shape[0]) , sep = '')
print('\033[92m' , 'Features: ' , '1' , sep = '')

print('\033[0m' , '\033[92m' , '\n' , '-'*25 , '\n' , sep='')

print('\033[1m' , '\033[91m' , 'X_val:' , '\033[0m' , sep='')
print('\033[92m' , 'Data Points :' , '{:,}'.format(X_val.shape[0]) , sep = '')
print('\033[92m' , 'Features: ' , X_val.shape[1] , sep = '')
print()
print('\033[1m' , '\033[91m' , 'y_val:' , '\033[0m' , sep='')
print('\033[92m' , 'Data Points :' , '{:,}'.format(y_val.shape[0]) , sep = '')
print('\033[92m' , 'Features: ' , '1' , sep = '')

print('\033[0m' , '\033[92m' , '\n' , '-'*25 , '\n' , sep='')

print('\033[1m' , '\033[91m' , 'X_test:' , '\033[0m' , sep='')
print('\033[92m' , 'Data Points :' , '{:,}'.format(X_test.shape[0]) , sep = '')
print('\033[92m' , 'Features: ' , X_test.shape[1] , sep = '')
print()
print('\033[1m' , '\033[91m' , 'y_test:' , '\033[0m' , sep='')
print('\033[92m' , 'Data Points :' , '{:,}'.format(y_test.shape[0]) , sep = '')
print('\033[92m' , 'Features: ' , '1' , sep = '')
# Out:
# Dataset Shape:
# Data Points: 10,000
# Features: 11
#
# -------------------------
#
# X:
# Data Points: 10,000
# Features: 10
#
# y:
# Data Points:10,000
# Features:1
#
# -------------------------
#
# X_train:
# Data Points :6,400
# Features: 11
#
# y_train:
# Data Points :6,400
# Features: 1
#
# -------------------------
#
# X_val:
# Data Points :1,600
# Features: 11
#
# y_val:
# Data Points :1,600
# Features: 1
#
# -------------------------
#
# X_test:
# Data Points :2,000
# Features: 11
#
# y_test:
# Data Points :2,000
# Features: 1

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** Gender Feature contains 2 Categories. Thus, it has been replaced with 1 New Feature.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2.** Geography Feature contains 3 Categories. Thus, it has been replaced with 2 New Features.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **3.** Overall, the Total No. of Features in X_train, X_va, and X_test will be incremented with 1 only.

# %%
# Standard Scaling the Features (Numerical Features in X_train, X_val, and X_test):
# Discrete Feature (NumOfProducts) and Boolean Features (HasCrCard and IsActiveMember) will be exluded from Scaling.

scaling_var = ['CreditScore' , 'Age' , 'Tenure' , 'Balance' , 'EstimatedSalary']

scaler = StandardScaler()

X_train[scaling_var] = scaler.fit_transform(X_train[scaling_var])
X_val[scaling_var] = scaler.transform(X_val[scaling_var])
X_test[scaling_var] = scaler.transform(X_test[scaling_var])

# %%
# Verifying the success of Standardization Process by calculating the Mean/St. Deviation of X_train:

print('\033[0m' , '\033[92m' , 'Numerical Features (' ,
      '\033[1m' , '\033[91m' , 'X_train' ,
      '\033[0m' , '\033[92m' , '):\n' , sep='')
for element in scaling_var:
    mean = np.mean(X_train[element])
    st_deviation = np.std(X_train[element])
    
    print('\033[0m' , '\033[92m' , 'Column: ' ,
          '\033[0m' , '\033[91m' ,  f"{element:<25}" ,
          '\033[0m' , '\033[92m' , 'Mean = ' , 
          '\033[0m' , '\033[91m' , '{0:.2f}'.format(mean) , 
          '\033[0m' , '\033[92m' , ' \t St. Deviation = ' , 
          '\033[0m' , '\033[91m' , '{0:.2f}'.format(st_deviation) , sep='')
# Out:
# Numerical Features (X_train):
#
# Column: CreditScore              Mean = 0.00 	 St. Deviation = 1.00
# Column: Age                      Mean = -0.00 	 St. Deviation = 1.00
# Column: Tenure                   Mean = 0.00 	 St. Deviation = 1.00
# Column: Balance                  Mean = 0.00 	 St. Deviation = 1.00
# Column: EstimatedSalary          Mean = -0.00 	 St. Deviation = 1.00

# %%
# Verifying the success of Standardization Process by calculating the Mean/St. Deviation of X_test:

print('\033[0m' , '\033[92m' , 'Numerical Features (' ,
      '\033[1m' , '\033[91m' , 'X_test' ,
      '\033[0m' , '\033[92m' , '):\n' , sep='')
for element in scaling_var:
    mean = np.mean(X_test[element])
    st_deviation = np.std(X_test[element])
    
    print('\033[0m' , '\033[92m' , 'Column: ' ,
          '\033[0m' , '\033[91m' ,  f"{element:<25}" ,
          '\033[0m' , '\033[92m' , 'Mean = ' , 
          '\033[0m' , '\033[91m' , '{0:.2f}'.format(mean) , 
          '\033[0m' , '\033[92m' , ' \t St. Deviation = ' , 
          '\033[0m' , '\033[91m' , '{0:.2f}'.format(st_deviation) , sep='')
# Out:
# Numerical Features (X_test):
#
# Column: CreditScore              Mean = 0.03 	 St. Deviation = 1.00
# Column: Age                      Mean = -0.01 	 St. Deviation = 0.97
# Column: Tenure                   Mean = 0.03 	 St. Deviation = 0.98
# Column: Balance                  Mean = 0.02 	 St. Deviation = 0.99
# Column: EstimatedSalary          Mean = 0.01 	 St. Deviation = 1.01

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** Both of X_train  and X_test have a Zero Mean and 1 Standard Deviation (Approximately).

# %%
# Ensuring that the new Dataframe is working by displaying the first 5 Data Rows in X_train:

X_train.head()
# Out:
#       CreditScore       Age    Tenure   Balance  NumOfProducts  HasCrCard  \
# 5292     0.976155 -1.047381  0.347046 -1.212523              2          1
# 3879     1.316949 -0.572048  1.377238  1.214872              2          0
# 6118    -0.190810  0.949016  0.003649  1.473810              1          0
# 4044     0.077695 -0.667115  1.033841 -1.212523              1          1
# 3202    -0.893054 -0.572048 -0.339749  0.961751              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_Germany  Geography_Spain  \
# 5292               0         0.939366                  0                0
# 3879               0         1.389376                  0                0
# 6118               0         0.692477                  0                0
# 4044               1        -0.347954                  0                0
# 3202               0        -0.647963                  0                0
#
#       Gender_Male
# 5292            0
# 3879            0
# ...

# %%
# Ensuring that the new Series is working by displaying the first 5 Data Rows in y_train:

y_train.head()
# Out:
# 5292    0
# 3879    1
# 6118    0
# 4044    0
# 3202    0
# Name: Exited, dtype: int64

# %%
# Ensuring that the new Dataframe is working by displaying the first 5 Data Rows in X_val:

X_val.head()
# Out:
#       CreditScore       Age    Tenure   Balance  NumOfProducts  HasCrCard  \
# 6919     1.358258 -0.572048  0.690443  1.850626              1          1
# 7849    -0.077211  0.188484  0.690443  1.264933              1          1
# 5810    -1.605625  0.283551  0.690443 -1.212523              2          0
# 594      1.327277 -1.237514 -0.339749  1.575456              2          0
# 2485     1.058772 -0.096715  0.347046  1.062786              1          0
#
#       IsActiveMember  EstimatedSalary  Geography_Germany  Geography_Spain  \
# 6919               1         1.159833                  0                0
# 7849               1        -0.882928                  1                0
# 5810               0         0.522003                  0                1
# 594                1        -1.080799                  0                1
# 2485               1        -1.160249                  0                0
#
#       Gender_Male
# 6919            1
# 7849            1
# ...

# %%
# Ensuring that the new Series is working by displaying the first 5 Data Rows in y_val:

y_val.head()
# Out:
# 6919    0
# 7849    0
# 5810    0
# 594     0
# 2485    0
# Name: Exited, dtype: int64

# %%
# Ensuring that the new Dataframe is working by displaying the first 5 Data Rows in X_test:

X_test.head()
# Out:
#       CreditScore       Age    Tenure   Balance  NumOfProducts  HasCrCard  \
# 4466    -2.452448 -0.381915 -1.026544 -1.212523              2          1
# 3754    -1.192540 -0.381915  1.033841  0.690558              1          1
# 9601     0.088023 -0.572048  0.690443  0.225938              1          1
# 9758    -0.975670  0.378617 -0.339749  0.800926              1          1
# 8577     1.069099  2.470081 -1.369941  0.965592              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_Germany  Geography_Spain  \
# 4466               1        -0.686197                  0                1
# 3754               1         0.611309                  0                1
# 9601               0         0.628769                  0                0
# 9758               1        -0.444630                  1                0
# 8577               1         0.367567                  1                0
#
#       Gender_Male
# 4466            1
# 3754            1
# ...

# %%
# Ensuring that the new Series is working by displaying the first 5 Data Rows in y_test:

y_test.head()
# Out:
# 4466    0
# 3754    0
# 9601    0
# 9758    0
# 8577    1
# Name: Exited, dtype: int64

# %%
# Summarizing the Shapes of Training, Validation, and Testing Subsets after One-Hot Encoding:

print('\033[1m' , '\033[91m' , 'Dataset Shape:' , '\033[0m' , sep='')
print('\033[92m' , 'Data Points: ' , '{:,}'.format(df.shape[0]) , sep = '')
print('\033[92m' , 'Features: ' , df.shape[1] , sep = '')

print('\033[0m' , '\033[92m' , '\n' , '-'*25 , '\n' , sep='')

print('\033[1m' , '\033[91m' , 'X:' , '\033[0m' , sep='')
print('\033[92m' , 'Data Points: ' , '{:,}'.format(X.shape[0]) , sep = '')
print('\033[92m' , 'Features: ' , X.shape[1] , sep = '')
print()
print('\033[1m' , '\033[91m' , 'y:' , '\033[0m' , sep='')
print('\033[92m' , 'Data Points:' , '{:,}'.format(y.shape[0]) , sep = '')
print('\033[92m' , 'Features:' , '1' , sep = '')

print('\033[0m' , '\033[92m' , '\n' , '-'*25 , '\n' , sep='')

print('\033[1m' , '\033[91m' , 'X_train:' , '\033[0m' , sep='')
print('\033[92m' , 'Data Points :' , '{:,}'.format(X_train.shape[0]) , sep = '')
print('\033[92m' , 'Features: ' , X_train.shape[1] , sep = '')
print()
print('\033[1m' , '\033[91m' , 'y_train:' , '\033[0m' , sep='')
print('\033[92m' , 'Data Points :' , '{:,}'.format(y_train.shape[0]) , sep = '')
print('\033[92m' , 'Features: ' , '1' , sep = '')

print('\033[0m' , '\033[92m' , '\n' , '-'*25 , '\n' , sep='')

print('\033[1m' , '\033[91m' , 'X_val:' , '\033[0m' , sep='')
print('\033[92m' , 'Data Points :' , '{:,}'.format(X_val.shape[0]) , sep = '')
print('\033[92m' , 'Features: ' , X_val.shape[1] , sep = '')
print()
print('\033[1m' , '\033[91m' , 'y_val:' , '\033[0m' , sep='')
print('\033[92m' , 'Data Points :' , '{:,}'.format(y_val.shape[0]) , sep = '')
print('\033[92m' , 'Features: ' , '1' , sep = '')

print('\033[0m' , '\033[92m' , '\n' , '-'*25 , '\n' , sep='')

print('\033[1m' , '\033[91m' , 'X_test:' , '\033[0m' , sep='')
print('\033[92m' , 'Data Points :' , '{:,}'.format(X_test.shape[0]) , sep = '')
print('\033[92m' , 'Features: ' , X_test.shape[1] , sep = '')
print()
print('\033[1m' , '\033[91m' , 'y_test:' , '\033[0m' , sep='')
print('\033[92m' , 'Data Points :' , '{:,}'.format(y_test.shape[0]) , sep = '')
print('\033[92m' , 'Features: ' , '1' , sep = '')
# Out:
# Dataset Shape:
# Data Points: 10,000
# Features: 11
#
# -------------------------
#
# X:
# Data Points: 10,000
# Features: 10
#
# y:
# Data Points:10,000
# Features:1
#
# -------------------------
#
# X_train:
# Data Points :6,400
# Features: 11
#
# y_train:
# Data Points :6,400
# Features: 1
#
# -------------------------
#
# X_val:
# Data Points :1,600
# Features: 11
#
# y_val:
# Data Points :1,600
# Features: 1
#
# -------------------------
#
# X_test:
# Data Points :2,000
# Features: 11
#
# y_test:
# Data Points :2,000
# Features: 1

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** Both of X_train, X_Val, and X_test have the same No. of Features.

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Green'> **Good to know!**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1. Definitions:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.1:** Sensitivity (Recall/True Positive Rate): Indicates how well the Model can capture the positive Classes and avoid False Negatives.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.2:** False Positive Rate: Indicates the Model tendency to make False Positive Errors (Classifying Negative Classes as Positive) .
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.3:** Specificity: Indicates how well the Model can avoid classifying Negative Classes as Positive.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.4:** Geometric Mean (G-Mean): Metric for Imbalanced Classification. If optimized, will seek a balance between the Sensitivity and the Specificity.
#
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2. Equations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2.1:** True Positive Rate (TPR) = True Positive / (True Positive + False Negative)
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2.2:** False Positive Rate (FPR) = False Positive / (False Positive + True Negative)
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2.3:** Specificity = 1 - False Positive Rate = True Negative / (False Positive + True Negative)
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2.4:** G-Mean = sqrt(Sensitivity * Specificity) = sqrt((TP / (TP + FN)) * (TN / (TN + FP))).
#
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> In ROC Curve, the Threshold with the largest G-Mean value is chosen.

# %%
# Defining a Function to Plot the Confusion Matrix:

def plot_confusion_matrix(cf , group_names=None , categories='auto' , xyplotlabels=True , sum_stats=True ,
                          count=True , percent=True , cbar=True , xyticks=True , figsize=None , cmap='Blues' , title=None):

    blanks = ['' for i in range(cf.size)]

    if group_names and len(group_names)==cf.size:
        group_labels = ['{}\n'.format(value) for value in group_names]
    else:
        group_labels = blanks

    if count:
        group_counts = ['{0:0.0f}\n'.format(value) for value in cf.flatten()]
    else:
        group_counts = blanks

    if percent:
        group_percentages = ['{0:.2%}'.format(value) for value in cf.flatten()/np.sum(cf)]
    else:
        group_percentages = blanks

    box_labels = [f'{v1}{v2}{v3}'.strip() for v1, v2, v3 in zip(group_labels , group_counts , group_percentages)]
    box_labels = np.asarray(box_labels).reshape(cf.shape[0] , cf.shape[1])

    if sum_stats:
        accuracy  = np.trace(cf) / float(np.sum(cf))

        if len(cf)==2:
            precision = cf[1,1] / sum(cf[:,1])
            recall    = cf[1,1] / sum(cf[1,:])
            f1_score  = 2*precision*recall / (precision + recall)

        else:
            stats_text = ''
    else:
        stats_text = ''

    if figsize==None:
        figsize = plt.rcParams.get('figure.figsize')

    if xyticks==False:
        categories=False

    plt.figure(figsize=figsize)
    sns.heatmap(cf , annot=box_labels , fmt='' , cmap=cmap , cbar=cbar , xticklabels=categories , yticklabels=categories)
    
    if xyplotlabels:
        plt.ylabel('Actual Class')
        plt.xlabel('Predicted Class')
              
    if len(cf)==2:
        print('\033[0m' , '\033[92m' , 'Accuracy = ' ,
              '\033[1m' , '\033[91m' , '{0:.3f}'.format(accuracy) , 
              '\033[0m' , '\033[92m' , '\nPrecision = ' ,
              '\033[1m' , '\033[91m' , '{0:.3f}'.format(precision) ,
              '\033[0m' , '\033[92m' , '\nRecall = ' ,
              '\033[1m' , '\033[91m' , '{0:.3f}'.format(recall) ,              
              '\033[0m' , '\033[92m' , '\nF1 Score = ' ,
              '\033[1m' , '\033[91m' , '{0:.3f}'.format(f1_score) , sep='')              
    else:
        print('\033[0m' , '\033[92m' , 'Accuracy = ' ,
              '\033[1m' , '\033[91m' , '{0:.3f}'.format(accuracy) , sep='')

# %%
# Defining a Function to Plot the ROC-AUC Curve:

def plot_roc_auc_curve(model , predictiors , validators):
    yhat_2 = model.predict(predictiors)

    yhat_2 = yhat_2[: , 0]
    fpr , tpr , thresholds1 = roc_curve(validators , yhat_2)
    gmeans1 = np.sqrt(tpr * (1-fpr))

    ix = np.argmax(gmeans1)
    
    global threshold_roc
    threshold_roc = thresholds1[ix]
    
    print('\033[0m' , '\033[92m' , 'Optimum Threshold = ' ,
          '\033[1m' , '\033[91m' , '{0:.6f}'.format(threshold_roc) ,
          '\033[0m' , '\033[92m' , ' at G-Mean = ' ,
          '\033[1m' , '\033[91m' , '{0:.3f}'.format(gmeans1[ix]) , sep='')

    plt.plot([0,1] , [0,1] , linestyle='--' , label='No Skill' , color='orange')
    plt.plot(fpr , tpr , marker='.' , color='orangered')
    plt.scatter(fpr[ix] , tpr[ix] , marker='o' , color='purple' , label='Best' , s=100)
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.show()

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Blue' > **Initial Model (Model 1):**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** No. of Layers: 4.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2.** No. of Neurons: 128 / 64 / 32 / 1.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **3.** Optimizer: Stochastic Gradient Descent (SGD).
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **4.** Metric: Accuracy.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **5.** No. of Epochs: 100.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **6.** Batch Size: 32.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **7.** Learning Rate: 0.001.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **8.** Regularization Method: Not used.

# %%
# Clearing the Previous Sessions:

backend.clear_session()
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
# Building model_1:
# kernel_initialize = 'he_uniform' or 'glorot_uniform' or 'random_normal'
# kernel_regularizer = regularizers.l1(0.01) or regularizers.l2(0.01)

model_1 = Sequential()

model_1.add(Dense(units=128 , activation = 'relu' , input_shape=(X_train.shape[1],)))

model_1.add(Dense(units=64 , activation='relu'))

model_1.add(Dense(units=32 , activation='relu'))

model_1.add(Dense(units=1 , activation = 'sigmoid'))

# %%
# Compiling model_1:

optimizer = tf.keras.optimizers.SGD(lr=0.001)
model_1.compile(loss= 'binary_crossentropy' , optimizer=optimizer , metrics=['accuracy'])

# %%
# Summarizing model_1:

model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 128)               1536
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 1)                 33
#
# ...
# Total params: 11,905
# Trainable params: 11,905
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** No. of Parameters (Input Layer) = (128 x 11) + 128 = 1,536.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2.** No. of Parameters (Hidden Layer) = (64 x 128) + 64 = 8,256.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **3.** No. of Parameters (Hidden Layer) = (32 x 64) + 32 = 2,080.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **4.** No. of Parameters (Output Layer) = (1 x 32) + 1 = 33.

# %%
# Training model_1:

start_time = time.time()

epochs = 100
history_1 = model_1.fit(X_train , y_train , epochs=epochs , validation_data=(X_val , y_val) , batch_size=32 , verbose=1)

end_time = time.time()
elapsed_time = end_time - start_time
print('\033[1m' , '\033[94m' , '\nExecution Time = ', '{:.5f}'.format(elapsed_time), ' Seconds!' , sep='')
# Out:
# Epoch 1/100
# 200/200 [==============================] - 1s 2ms/step - loss: 0.6526 - accuracy: 0.7138 - val_loss: 0.6153 - val_accuracy: 0.7919
# Epoch 2/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5890 - accuracy: 0.7953 - val_loss: 0.5639 - val_accuracy: 0.7962
# Epoch 3/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5487 - accuracy: 0.7962 - val_loss: 0.5319 - val_accuracy: 0.7962
# Epoch 4/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5235 - accuracy: 0.7962 - val_loss: 0.5119 - val_accuracy: 0.7962
# Epoch 5/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5079 - accuracy: 0.7962 - val_loss: 0.4996 - val_accuracy: 0.7962
# Epoch 6/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4982 - accuracy: 0.7962 - val_loss: 0.4917 - val_accuracy: 0.7962
# Epoch 7/100
# ...

# %%
# Plotting the Loss on both Training and Validation Subsets for model_1:

plt.plot(history_1.history['loss'] , label= 'Training')
plt.plot(history_1.history['val_loss'] , label= 'Validation')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** Although no Noise - Fluctuations - in the Validation Curve and identical values of Losses on both Training and Validation Curves, Model's Losses are considered somehow high on both Curves (Above 0.4).
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2.** Using different Optimizer may result in decreasing the Losses.

# %%
# Finding the Predictions of model_1 using Threshold = 0.50:

threshold_1 = 0.5
y_result = model_1.predict(X_val)
y_result_1 = (y_result > threshold_1)

# %%
# Displaying the Classification Report of model_1:

print(classification_report(y_val , y_result_1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.99      0.90      1274
#            1       0.75      0.17      0.27       326
#
#     accuracy                           0.82      1600
#    macro avg       0.79      0.58      0.58      1600
# weighted avg       0.81      0.82      0.77      1600

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** Although the Recall Value for Class 0 is excellent, a very low Recall Value is found for Class 1.

# %%
# Plotting the Confusion Matrix of model_1:

cm = confusion_matrix(y_val , y_result_1)
labels = ['True Negative' , 'False Positive' , 'False Negative' , 'True Positive']
categories = ['Not Exited' , 'Exited']
plot_confusion_matrix(cm , group_names=labels , categories=categories , cmap='viridis')
# Out:
# Accuracy = 0.819
# Precision = 0.750
# Recall = 0.166
# F1 Score = 0.271

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** As expected, the results obtained from Classification Report has significantly affected the overall Recall Value.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2.** Recall Value is very low due to the presence of 272 Customers which have been wrongly classified as Not Exited although they have high potential to exit.

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Blue' > **Model Improvement (Model 2):**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** No. of Layers: 4. <font color='Green'> **Unchanged**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2.** No. of Neurons: 128 / 64 / 32 / 1. <font color='Green'> **Unchanged**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **3.** Optimizer: Adaptive Moment Estimation (Adam). <font color='Orange'> **Changed**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **4.** Metric: Accuracy. <font color='Green'> **Unchanged**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **5.** No. of Epochs: 100. <font color='Green'> **Unchanged**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **6.** Batch Size: 32. <font color='Green'> **Unchanged**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **7.** Learning Rate: 0.001. <font color='Green'> **Unchanged**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **8.** Regularization Method: Not used. <font color='Green'> **Unchanged**

# %%
# Clearing the Previous Sessions:

backend.clear_session()
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
# Building model_2:
# kernel_initialize = 'he_uniform' or 'glorot_uniform' or 'random_normal'
# kernel_regularizer = regularizers.l1(0.01) or regularizers.l2(0.01)

model_2 = Sequential()

model_2.add(Dense(units=128 , activation = 'relu' , input_shape=(X_train.shape[1],)))

model_2.add(Dense(units=64 , activation='relu'))

model_2.add(Dense(units=32 , activation='relu'))

model_2.add(Dense(units=1 , activation = 'sigmoid'))

# %%
# Compiling model_2:

optimizer = tf.keras.optimizers.Adam(lr=0.001)
model_2.compile(loss= 'binary_crossentropy' , optimizer=optimizer , metrics=['accuracy'])

# %%
# Summarizing model_2:

model_2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 128)               1536
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 1)                 33
#
# ...
# Total params: 11,905
# Trainable params: 11,905
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Training model_2:

start_time = time.time()

epochs = 100
history_2 = model_2.fit(X_train , y_train , epochs=epochs , validation_data=(X_val , y_val) , batch_size=32 , verbose=1)

end_time = time.time()
elapsed_time = end_time - start_time
print('\033[1m' , '\033[94m' , '\nExecution Time = ', '{:.5f}'.format(elapsed_time), ' Seconds!' , sep='')
# Out:
# Epoch 1/100
# 200/200 [==============================] - 1s 2ms/step - loss: 0.4499 - accuracy: 0.8064 - val_loss: 0.4131 - val_accuracy: 0.8238
# Epoch 2/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4029 - accuracy: 0.8327 - val_loss: 0.3966 - val_accuracy: 0.8325
# Epoch 3/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3835 - accuracy: 0.8439 - val_loss: 0.3810 - val_accuracy: 0.8338
# Epoch 4/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3642 - accuracy: 0.8500 - val_loss: 0.3890 - val_accuracy: 0.8325
# Epoch 5/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3510 - accuracy: 0.8556 - val_loss: 0.3639 - val_accuracy: 0.8406
# Epoch 6/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3375 - accuracy: 0.8612 - val_loss: 0.3669 - val_accuracy: 0.8394
# Epoch 7/100
# ...

# %%
# Plotting the Loss on both Training and Validation Subsets for model_2:

plt.plot(history_2.history['loss'] , label= 'Training')
plt.plot(history_2.history['val_loss'] , label= 'Validation')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** Severe Over-Fitting is quite noticed in the Performance of Model using Adam Optimizer - Gap between Training and Validation Curves is rapidly increasing.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2.** In addition to Over-Fitting, visible Noise - Fluctuations - is observed in the Validation Curve.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **3.** Overall, due to good readings of Loss at the early beginning of the curves, Early Stopping Method might be helful in stopping the learning process at a point where both Training and Validation Losses are considered somehow good (Below 0.4).

# %%
# Finding the Optimum Threshold of model_2 using Receiver Operating Characteristic (ROC) Curve:

plot_roc_auc_curve(model_2 , X_train , y_train)

# Keeping Threshold Finder within the same Code Block to avoid overwritten the Global Variable:

threshold_2 = threshold_roc
# Out:
# Optimum Threshold = 0.499059 at G-Mean = 0.983

# %%
# Finding the Predictions of model_2 using ROC Threshold:

print('\033[0m' , '\033[92m' , 'Threshold (' ,
      '\033[1m' , '\033[91m' , 'model_2' ,
      '\033[0m' , '\033[92m' , ') = '
      '\033[0m' , '\033[92m' , threshold_2 , sep='')

y_result = model_2.predict(X_val)
y_result_2 = (y_result > threshold_2)
# Out:
# Threshold (model_2) = 0.49905884

# %%
# Displaying the Classification Report of model_2:

print(classification_report(y_val , y_result_2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.86      0.87      1274
#            1       0.49      0.52      0.50       326
#
#     accuracy                           0.79      1600
#    macro avg       0.68      0.69      0.68      1600
# weighted avg       0.79      0.79      0.79      1600

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** Although the Recall value for Class 0 has decreased from 0.96 (model_1) to 0.86, it has increased from 0.25 (model_1) to 0.52.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2.** Despite of such improvement in terms of decreasing the gap, Recall value for Class 1 is not even close to its value on Class 0. Thus, model_2 still needs more improvement.

# %%
# Plotting the Confusion Matrix of model_2:

cm = confusion_matrix(y_val , y_result_2)
labels = ['True Negative' , 'False Positive' , 'False Negative' , 'True Positive']
categories = ['Not Exited' , 'Exited']
plot_confusion_matrix(cm , group_names=labels , categories=categories , cmap='viridis')
# Out:
# Accuracy = 0.790
# Precision = 0.486
# Recall = 0.515
# F1 Score = 0.500

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** Recall value has significantly increased from 0.166 (model_1) to 0.515 (model_2).
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2.** FN has also significantly decreased from 272 (model_1) to 158 (model_2).
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **3.** Such results might be interpreted as a better performance of Adam Optimizer over SGD Optimizer.

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Blue' > **Model Improvement (Model 3):**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** No. of Layers: 4. <font color='Green'> **Unchanged**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2.** No. of Neurons: 128 / 64 / 32 / 1. <font color='Green'> **Unchanged**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **3.** Optimizer: Adaptive Moment Estimation (Adam). <font color='Green'> **Unchanged**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **4.** Metric: Accuracy. <font color='Green'> **Unchanged**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **5.** No. of Epochs: 100. <font color='Green'> **Unchanged**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **6.** Batch Size: 32. <font color='Green'> **Unchanged**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **7.** Learning Rate: 0.001. <font color='Green'> **Unchanged**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **8.** Regularization Method: Early Stopping. <font color='Orange'> **Changed**

# %%
# Clearing the Previous Sessions:

backend.clear_session()
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
# Building model_3:
# kernel_initialize = 'he_uniform' or 'glorot_uniform' or 'random_normal'
# kernel_regularizer = regularizers.l1(0.01) or regularizers.l2(0.01)

model_3 = Sequential()

model_3.add(Dense(units=128 , activation = 'relu' ,  input_shape=(X_train.shape[1],)))

model_3.add(Dense(units=64 , activation='relu'))

model_3.add(Dense(units=32 , activation='relu'))

model_3.add(Dense(units=1 , activation = 'sigmoid'))

# %%
# Compiling model_3:

optimizer = tf.keras.optimizers.Adam(lr=0.001)
model_3.compile(loss= 'binary_crossentropy' , optimizer=optimizer , metrics=['accuracy'])

# %%
# Summarizing model_3:

model_3.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 128)               1536
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 1)                 33
#
# ...
# Total params: 11,905
# Trainable params: 11,905
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Training model_3:

start_time = time.time()

epochs = 100
early_stopping = callbacks.EarlyStopping(monitor='val_loss' , min_delta=0.001 , patience=5)
history_3 = model_3.fit(X_train , y_train , epochs=epochs , validation_data=(X_val , y_val) , batch_size=32 , callbacks=[early_stopping] , verbose=1)

end_time = time.time()
elapsed_time = end_time - start_time
print('\033[1m' , '\033[94m' , '\nExecution Time = ', '{:.5f}'.format(elapsed_time), ' Seconds!' , sep='')
# Out:
# Epoch 1/100
# 200/200 [==============================] - 1s 2ms/step - loss: 0.4499 - accuracy: 0.8064 - val_loss: 0.4131 - val_accuracy: 0.8238
# Epoch 2/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4029 - accuracy: 0.8327 - val_loss: 0.3966 - val_accuracy: 0.8325
# Epoch 3/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3835 - accuracy: 0.8439 - val_loss: 0.3810 - val_accuracy: 0.8338
# Epoch 4/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3642 - accuracy: 0.8500 - val_loss: 0.3890 - val_accuracy: 0.8325
# Epoch 5/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3510 - accuracy: 0.8556 - val_loss: 0.3639 - val_accuracy: 0.8406
# Epoch 6/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3375 - accuracy: 0.8612 - val_loss: 0.3669 - val_accuracy: 0.8394
# Epoch 7/100
# ...

# %%
# Plotting the Loss on both Training and Validation Subsets for model_3:

plt.plot(history_3.history['loss'] , label= 'Training')
plt.plot(history_3.history['val_loss'] , label= 'Validation')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** As expected, using of Early Stopping has stopped the learning process at the very early epochs (13) before the model start to Over-Fitting and a gap is being increased between curves.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2.** As a result, higher recall value and lower FN are expected.

# %%
# Finding the Optimum Threshold of model_3 using Receiver Operating Characteristic (ROC) Curve:

plot_roc_auc_curve(model_3 , X_train , y_train)

# Keeping Threshold Finder within the same Code Block to avoid overwritten the Global Variable:

threshold_3 = threshold_roc
# Out:
# Optimum Threshold = 0.146195 at G-Mean = 0.820

# %%
# Finding the Predictions of model_3 using ROC-AUC Threshold:

print('\033[0m' , '\033[92m' , 'Threshold (' ,
      '\033[1m' , '\033[91m' , 'model_3' ,
      '\033[0m' , '\033[92m' , ') = '
      '\033[0m' , '\033[92m' , threshold_3 , sep='')

y_result = model_3.predict(X_val)
y_result_3 = (y_result > threshold_3)
# Out:
# Threshold (model_3) = 0.14619482

# %%
# Displaying the Classification Report of model_3:

print(classification_report(y_val , y_result_3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.80      0.86      1274
#            1       0.49      0.75      0.60       326
#
#     accuracy                           0.79      1600
#    macro avg       0.71      0.78      0.73      1600
# weighted avg       0.84      0.79      0.81      1600

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** Although the Recall Value of Class 0 continues to decrease, its value for Class 1 continues to increase.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2.** As a result, the gap between classes has shrunk and a balance has started to occur.

# %%
# Plotting the Confusion Matrix of model_3:

cm = confusion_matrix(y_val , y_result_3)
labels = ['True Negative' , 'False Positive' , 'False Negative' , 'True Positive']
categories = ['Not Exited' , 'Exited']
plot_confusion_matrix(cm , group_names=labels , categories=categories , cmap='viridis')
# Out:
# Accuracy = 0.792
# Precision = 0.494
# Recall = 0.755
# F1 Score = 0.597

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** A quite good improvement in Recall value as it has increased from 0.515 (model_2) to 0.755 (model_3).
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2.** Further to Recall, FN has decreased significantly - Approximately by half - from 158 (model_2) to just 80 (model_3).

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Blue' > **Model Improvement (Model 4):**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** No. of Layers: 4. <font color='Green'> **Unchanged**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2.** No. of Neurons: 128 / 64 / 32 / 1. <font color='Green'> **Unchanged**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **3.** Optimizer: Adaptive Moment Estimation (Adam). <font color='Green'> **Unchanged**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **4.** Metric: Accuracy. <font color='Green'> **Unchanged**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **5.** No. of Epochs: 100. <font color='Green'> **Unchanged**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **6.** Batch Size: 32. <font color='Green'> **Unchanged**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **7.** Learning Rate: 0.001. <font color='Green'> **Unchanged**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **8.** Regularization Method: Early Stopping and Dropout <font color='Orange'> **Changed**

# %%
# Clearing the Previous Sessions:

backend.clear_session()
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
# Building model_4:
# kernel_initialize = 'he_uniform' or 'glorot_uniform' or 'random_normal'
# kernel_regularizer = regularizers.l1(0.01) or regularizers.l2(0.01)

model_4 = Sequential()

model_4.add(Dense(units=128 , activation = 'relu' , input_shape=(X_train.shape[1],)))
model_4.add(Dropout(0.2))

model_4.add(Dense(units=64 , activation='relu'))
model_4.add(Dropout(0.2))

model_4.add(Dense(units=32 , activation='relu'))

model_4.add(Dense(units=1 , activation = 'sigmoid'))

# %%
# Compiling model_4:

optimizer = tf.keras.optimizers.Adam(lr=0.001)
model_4.compile(loss= 'binary_crossentropy' , optimizer=optimizer , metrics=['accuracy'])

# %%
# Summarizing model_4:

model_4.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 128)               1536
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 1)                 33
#
# ...
# Total params: 11,905
# Trainable params: 11,905
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Training model_4:

start_time = time.time()

epochs = 100
early_stopping = callbacks.EarlyStopping(monitor='val_loss' , min_delta=0.001 , patience=5)
history_4 = model_4.fit(X_train , y_train , epochs=epochs , validation_data=(X_val , y_val) , batch_size=32 , callbacks=[early_stopping] , verbose=1)

end_time = time.time()
elapsed_time = end_time - start_time
print('\033[1m' , '\033[94m' , '\nExecution Time = ', '{:.5f}'.format(elapsed_time), ' Seconds!' , sep='')
# Out:
# Epoch 1/100
# 200/200 [==============================] - 1s 2ms/step - loss: 0.4669 - accuracy: 0.7930 - val_loss: 0.4225 - val_accuracy: 0.8044
# Epoch 2/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4244 - accuracy: 0.8173 - val_loss: 0.4071 - val_accuracy: 0.8256
# Epoch 3/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4112 - accuracy: 0.8280 - val_loss: 0.3999 - val_accuracy: 0.8294
# Epoch 4/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3999 - accuracy: 0.8356 - val_loss: 0.3972 - val_accuracy: 0.8294
# Epoch 5/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3940 - accuracy: 0.8388 - val_loss: 0.3955 - val_accuracy: 0.8313
# Epoch 6/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3832 - accuracy: 0.8436 - val_loss: 0.3842 - val_accuracy: 0.8331
# Epoch 7/100
# ...

# %%
# Plotting the Loss on both Training and Validation Subsets for model_4:

plt.plot(history_4.history['loss'] , label= 'Training')
plt.plot(history_4.history['val_loss'] , label= 'Validation')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** Dropout has significantly decreased the gap between Training and Validation curves in addition to achieving smoother Validation curve with less Noise (Fluctuations).
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2.** Furthermore, the No. of Epochs has been increased from 13 (model_3) to 24 (model_4). Such increase might help the model to exposed more to Training Data Point.

# %%
# Finding the Optimum Threshold of model_4 using Receiver Operating Characteristic (ROC) Curve:

plot_roc_auc_curve(model_4 , X_train , y_train)

# Keeping Threshold Finder within the same Code Block to avoid overwritten the Global Variable:

threshold_4 = threshold_roc
# Out:
# Optimum Threshold = 0.159635 at G-Mean = 0.816

# %%
# Finding the Predictions of model_4 using ROC-AUC Threshold:

print('\033[0m' , '\033[92m' , 'Threshold (' ,
      '\033[1m' , '\033[91m' , 'model_4' ,
      '\033[0m' , '\033[92m' , ') = '
      '\033[0m' , '\033[92m' , threshold_4 , sep='')

y_result = model_4.predict(X_val)
y_result_4 = (y_result > threshold_4)
# Out:
# Threshold (model_4) = 0.15963462

# %%
# Displaying the Classification Report of model_4:

print(classification_report(y_val , y_result_4))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.82      0.87      1274
#            1       0.51      0.74      0.60       326
#
#     accuracy                           0.80      1600
#    macro avg       0.72      0.78      0.73      1600
# weighted avg       0.84      0.80      0.81      1600

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** Although of improvement in terms of Loss, gap between Recall values has increased from 0.05 (model_3) to 0.08.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2.** Such increasing will affect the Total Recall as well as FN.

# %%
# Plotting the Confusion Matrix of model_4:

cm = confusion_matrix(y_val , y_result_4)
labels = ['True Negative' , 'False Positive' , 'False Negative' , 'True Positive']
categories = ['Not Exited' , 'Exited']
plot_confusion_matrix(cm , group_names=labels , categories=categories , cmap='viridis')
# Out:
# Accuracy = 0.800
# Precision = 0.506
# Recall = 0.739
# F1 Score = 0.601

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** As expected, Recall value has decreased from 0.755 (model_3) to 0.739.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2.** Further to Recall, FN has increased from 80 (model_3) to 85.

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **So far:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** model_3 perfroms better than model_4 in terms of lower gap between Class's Recall values, higher Overall Recall value, and lower FN.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2.** model_4 performs better than model_3 in terms of smaller gap between Training and Validation curves, in addition to more stable and less fluctuated Validation Curve.

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Blue' > **Model Improvement (Model 5):**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> Improving the Model Performance by using Grid Search Mechanism:

# %%
# Clearing the Previous Sessions:

backend.clear_session()
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
# Defining the Model's Function:

def model_x(drop_out , learning_rate):  
    np.random.seed(1337)
    
    model = Sequential()
    
    model.add(Dense(units=128 , activation = 'relu' , input_shape=(X_train.shape[1],)))
    
    model.add(Dense(units=64 , activation='relu'))
    model.add(Dropout(drop_out))
    
    model.add(Dense(units=32 , activation='relu'))
    
    model.add(Dense(units=1 , activation = 'sigmoid')) 

    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    model.compile(loss= 'binary_crossentropy' , optimizer=optimizer , metrics=['accuracy'])  

    return model

# %%
# Defining the Grid Search Scope:

keras_estimator = KerasClassifier(build_fn=model_x, verbose=1)
param_grid = {'drop_out' : [0.1 , 0.2 , 0.3] , 
              'learning_rate' : [0.001 , 0.01 , 0.1] ,
              'batch_size' : [32 , 64 , 128]}

kfold_splits = 5
grid = GridSearchCV(estimator=keras_estimator , verbose=1 , cv=kfold_splits , param_grid=param_grid , n_jobs=-1)

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** 3x3 Grid Space with 5 Folds will result in 3 x 3 x 3 x 5 = 135 Fits.

# %%
# Finding the Best Model using Grid Search Mechanism:

start_time = time.time()

grid_result = grid.fit(X_train , y_train , validation_data=(X_val , y_val) , verbose=1) 

end_time = time.time()
elapsed_time = end_time - start_time
print('\033[1m' , '\033[94m' , '\nExecution Time = ', '{:.5f}'.format(elapsed_time), ' Seconds!' , sep='')
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# 200/200 [==============================] - 1s 2ms/step - loss: 0.4402 - accuracy: 0.8145 - val_loss: 0.4117 - val_accuracy: 0.8244
#
# Execution Time = 39.49265 Seconds!

# %%
# Displaying the Best Result and Hyperparameters: 

print('\033[0m' , '\033[92m' , 'Best Model Score = ' , 
      '\033[1m' , '\033[91m' , '{:.3f}'.format(grid_result.best_score_) , sep='')
print('\033[0m' , '\033[92m' , 'Best Hyperparameter (Batch Size) = ' , 
      '\033[1m' , '\033[91m' , grid_result.best_params_['batch_size'] , sep='')
print('\033[0m' , '\033[92m' , 'Best Hyperparameter (Learning Rate) = ' , 
      '\033[1m' , '\033[91m' , grid_result.best_params_['learning_rate'] , sep='')
print('\033[0m' , '\033[92m' , 'Best Hyperparameter (Dropout Rate) = ' , 
      '\033[1m' , '\033[91m' , grid_result.best_params_['drop_out'] , sep='')
# Out:
# Best Model Score = 0.827
# Best Hyperparameter (Batch Size) = 32
# Best Hyperparameter (Learning Rate) = 0.01
# Best Hyperparameter (Dropout Rate) = 0.1

# %%
# Building model_5:

model_5 = model_x(drop_out=grid_result.best_params_['drop_out'] , learning_rate=grid_result.best_params_['learning_rate'])

# %%
# Summarizing model_5:

model_5.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_4 (Dense)             (None, 128)               1536
#
#  dense_5 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_6 (Dense)             (None, 32)                2080
#
#  dense_7 (Dense)             (None, 1)                 33
#
# ...
# Total params: 11,905
# Trainable params: 11,905
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Training model_5:

start_time = time.time()

epochs = 100
early_stopping = callbacks.EarlyStopping(monitor='val_loss' , min_delta=0.001 , patience=5)
history_5 = model_5.fit(X_train , y_train , epochs=epochs , validation_data=(X_val , y_val) , 
                        batch_size=grid_result.best_params_['batch_size'] , callbacks=[early_stopping] , verbose=1)

end_time = time.time()
elapsed_time = end_time - start_time
print('\033[1m' , '\033[94m' , '\nExecution Time = ', '{:.5f}'.format(elapsed_time), ' Seconds!' , sep='')
# Out:
# Epoch 1/100
# 200/200 [==============================] - 1s 2ms/step - loss: 0.4378 - accuracy: 0.8200 - val_loss: 0.4182 - val_accuracy: 0.8231
# Epoch 2/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4023 - accuracy: 0.8352 - val_loss: 0.4135 - val_accuracy: 0.8075
# Epoch 3/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3713 - accuracy: 0.8439 - val_loss: 0.3888 - val_accuracy: 0.8213
# Epoch 4/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3511 - accuracy: 0.8577 - val_loss: 0.3728 - val_accuracy: 0.8469
# Epoch 5/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3486 - accuracy: 0.8577 - val_loss: 0.3576 - val_accuracy: 0.8469
# Epoch 6/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3417 - accuracy: 0.8609 - val_loss: 0.3901 - val_accuracy: 0.8281
# Epoch 7/100
# ...

# %%
# Plotting the Loss on both Training and Validation Subsets for model_5:

plt.plot(history_5.history['loss'] , label= 'Training')
plt.plot(history_5.history['val_loss'] , label= 'Validation')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** Noise in Validation curve is back again; although of small gap between curves at the end of training process, quite fluctuation are well observed in the path of convergence.

# %%
# Finding the Optimum Threshold of model_5 using Receiver Operating Characteristic (ROC) Curve:

plot_roc_auc_curve(model_5 , X_train , y_train)

# Keeping Threshold Finder within the same Code Block to avoid overwritten the Global Variable:

threshold_5 = threshold_roc
# Out:
# Optimum Threshold = 0.132650 at G-Mean = 0.811

# %%
# Finding the Predictions of model_5 using ROC-AUC Threshold:

print('\033[0m' , '\033[92m' , 'Threshold (' ,
      '\033[1m' , '\033[91m' , 'model_5' ,
      '\033[0m' , '\033[92m' , ') = '
      '\033[0m' , '\033[92m' , threshold_5 , sep='')

y_result = model_5.predict(X_val)
y_result_5 = (y_result > threshold_5)
# Out:
# Threshold (model_5) = 0.13265038

# %%
# Displaying the Classification Report of model_5:

print(classification_report(y_val , y_result_5))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.74      0.82      1274
#            1       0.44      0.79      0.56       326
#
#     accuracy                           0.75      1600
#    macro avg       0.68      0.77      0.69      1600
# weighted avg       0.83      0.75      0.77      1600

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** Gap between Recall values has slightly decreased from 0.08 (model_4) to 0.06.

# %%
# Plotting the Confusion Matrix of model_5:

cm = confusion_matrix(y_val , y_result_5)
labels = ['True Negative' , 'False Positive' , 'False Negative' , 'True Positive']
categories = ['Not Exited' , 'Exited']
plot_confusion_matrix(cm , group_names=labels , categories=categories , cmap='viridis')
# Out:
# Accuracy = 0.750
# Precision = 0.437
# Recall = 0.791
# F1 Score = 0.563

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** As expected, Recall value has slightly increased from 0.739 (model_4) to 0.748.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2.** Further to Recall, FN has decreased from 85 (model_4) to 82.

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **So far:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** Both model_3 and model_5 perfroms better than model_4 in terms of lower gap between Class's Recall values, higher Overall Recall value, and lower FN.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2.** model_4 performs better than both model_3 and model_4 in terms of smaller gap between Training and Validation curves, in addition to more stable and less fluctuated Validation Curve.

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Blue' > **Model Improvement (Model 6):**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> Improving the Model Performance by Balancing the Classes (Over-Sampling Mechanism) and using the best achieved Hyperparameters (Grid Search):

# %%
# Over-Sampling X_train and y_train:

sm = SMOTE(sampling_strategy=1.0 , k_neighbors=5 , random_state=1)
X_train_over , y_train_over = sm.fit_resample(X_train , y_train)

# %%
# Displaying the contents of both X and y before & after Over-Sampling:

print('\033[1m' , '\033[91m' , 'Training Subset (Before Over-Sampling):' , '\033[0m' , sep='')
print('\033[92m' , 'No. of False Cases (0): {0} ({1:0.2f}%)'. format(len(y_train[y_train[:]==0]) , 
     (len(y_train[y_train[:]==0])/len(y_train)) * 100) , sep='')
print('\033[92m' , 'No. of True Cases (1): {0} ({1:0.2f}%)'. format(len(y_train[y_train[:]==1]) , 
     (len(y_train[y_train[:]==1])/len(y_train)) * 100) , '\n' , sep='')

print('\033[1m' , '\033[91m' , 'Training Subset (After Over-Sampling):' , '\033[0m' , sep='')
print('\033[92m' , 'No. of False Cases (0): {0} ({1:0.2f}%)'. format(len(y_train_over[y_train_over[:]==0]) , 
     (len(y_train_over[y_train_over[:]==0])/len(y_train_over)) * 100) , sep='')
print('\033[92m' , 'No. of True Cases (1): {0} ({1:0.2f}%)'. format(len(y_train_over[y_train_over[:]==1]) , 
     (len(y_train_over[y_train_over[:]==1])/len(y_train_over)) * 100) , '\n' , sep='')

print('\033[1m' , '\033[91m' , 'Shapes:' , '\033[0m' , sep='')
print('\033[0m' , '\033[92m' , 'X_train Shape (Before Over-Sampling): ', '\033[0m' , '\033[92m' , X_train.shape , sep='')
print('\033[0m' , '\033[92m' , 'y_train Shape (Before Over-Sampling): ', '\033[0m' , '\033[92m' , y_train.shape , sep='')
print()
print('\033[0m' , '\033[92m' , 'X_train Shape (After Over-Sampling): ', '\033[0m' , '\033[92m' , X_train_over.shape , sep='')
print('\033[0m' , '\033[92m' , 'y_train Shape (After Over-Sampling): ', '\033[0m' , '\033[92m' , y_train_over.shape , sep='')
# Out:
# Training Subset (Before Over-Sampling):
# No. of False Cases (0): 5096 (79.62%)
# No. of True Cases (1): 1304 (20.38%)
#
# Training Subset (After Over-Sampling):
# No. of False Cases (0): 5096 (50.00%)
# No. of True Cases (1): 5096 (50.00%)
#
# Shapes:
# X_train Shape (Before Over-Sampling): (6400, 11)
# y_train Shape (Before Over-Sampling): (6400,)
#
# X_train Shape (After Over-Sampling): (10192, 11)
# y_train Shape (After Over-Sampling): (10192,)

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** Using sampling_strategy equals to 1, the final No. of Minority Class (1) will equal to the No. of Majority Class (0). Thus, total No. of Data Points will be 5096 + 5096 = 10,192.

# %%
# Clearing the Previous Sessions:

backend.clear_session()
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
# Building model_6:
# kernel_initialize = 'he_uniform' or 'glorot_uniform' or 'random_normal'
# kernel_regularizer = regularizers.l1(0.01) or regularizers.l2(0.01)

model_6 = Sequential()

model_6.add(Dense(units=128 , activation = 'relu' , input_shape=(X_train.shape[1],)))

model_6.add(Dense(units=64 , activation='relu'))
model_6.add(Dropout(0.2))

model_6.add(Dense(units=32 , activation='relu'))

model_6.add(Dense(units=1 , activation = 'sigmoid'))

# %%
# Compiling model_6:

optimizer = tf.keras.optimizers.Adam(lr=0.01)
model_6.compile(loss= 'binary_crossentropy' , optimizer=optimizer , metrics=['accuracy'])

# %%
# Summarizing model_6:

model_6.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 128)               1536
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 1)                 33
#
# ...
# Total params: 11,905
# Trainable params: 11,905
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Training model_6:

start_time = time.time()

epochs = 100
early_stopping = callbacks.EarlyStopping(monitor='val_loss' , min_delta=0.001 , patience=5)
history_6 = model_6.fit(X_train_over , y_train_over , epochs=epochs , validation_data=(X_val , y_val) , batch_size=32 , callbacks=[early_stopping] , verbose=1)

end_time = time.time()
elapsed_time = end_time - start_time
print('\033[1m' , '\033[94m' , '\nExecution Time = ', '{:.5f}'.format(elapsed_time), ' Seconds!' , sep='')
# Out:
# Epoch 1/100
# 319/319 [==============================] - 1s 2ms/step - loss: 0.5188 - accuracy: 0.7444 - val_loss: 0.4657 - val_accuracy: 0.7594
# Epoch 2/100
# 319/319 [==============================] - 1s 2ms/step - loss: 0.4548 - accuracy: 0.7817 - val_loss: 0.4341 - val_accuracy: 0.8131
# Epoch 3/100
# 319/319 [==============================] - 1s 2ms/step - loss: 0.4281 - accuracy: 0.8025 - val_loss: 0.5026 - val_accuracy: 0.7544
# Epoch 4/100
# 319/319 [==============================] - 1s 2ms/step - loss: 0.4173 - accuracy: 0.8081 - val_loss: 0.4316 - val_accuracy: 0.7894
# Epoch 5/100
# 319/319 [==============================] - 1s 2ms/step - loss: 0.4078 - accuracy: 0.8131 - val_loss: 0.5310 - val_accuracy: 0.7588
# Epoch 6/100
# 319/319 [==============================] - 1s 2ms/step - loss: 0.3974 - accuracy: 0.8163 - val_loss: 0.4519 - val_accuracy: 0.7869
# Epoch 7/100
# ...

# %%
# Plotting the Loss on both Training and Validation Subsets for model_6:

plt.plot(history_6.history['loss'] , label= 'Training')
plt.plot(history_6.history['val_loss'] , label= 'Validation')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** model_6 has been trained using the best Hyperparameters combination obtained from Grid Search (Learning Rate = 0.01, Validation Split = 32, and Dropout = 0.3).
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2.** Losses curves has become worse with higher Loss (Above 0.4) and more Noise on Validation curve.

# %%
# Finding the Optimum Threshold of model_6 using Receiver Operating Characteristic (ROC) Curve:

plot_roc_auc_curve(model_6 , X_train_over , y_train_over)

# Keeping Threshold Finder within the same Code Block to avoid overwritten the Global Variable:

threshold_6 = threshold_roc
# Out:
# Optimum Threshold = 0.484669 at G-Mean = 0.847

# %%
# Finding the Predictions of model_6 using ROC-AUC Threshold:

print('\033[0m' , '\033[92m' , 'Threshold (' ,
      '\033[1m' , '\033[91m' , 'model_6' ,
      '\033[0m' , '\033[92m' , ') = '
      '\033[0m' , '\033[92m' , threshold_6 , sep='')

y_result = model_6.predict(X_val)
y_result_6 = (y_result > threshold_6)
# Out:
# Threshold (model_6) = 0.48466864

# %%
# Displaying the Classification Report of model_6:

print(classification_report(y_val , y_result_6))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.80      0.85      1274
#            1       0.47      0.71      0.56       326
#
#     accuracy                           0.78      1600
#    macro avg       0.69      0.75      0.71      1600
# weighted avg       0.82      0.78      0.79      1600

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** Gap between Recall values has increased to 0.09.

# %%
# Plotting the Confusion Matrix of model_6:

cm = confusion_matrix(y_val , y_result_6)
labels = ['True Negative' , 'False Positive' , 'False Negative' , 'True Positive']
categories = ['Not Exited' , 'Exited']
plot_confusion_matrix(cm , group_names=labels , categories=categories , cmap='viridis')
# Out:
# Accuracy = 0.777
# Precision = 0.469
# Recall = 0.706
# F1 Score = 0.564

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** Recall Values has decreased significantly from 0.748 (model_5) to 0.706.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2.** Further to Recall, FN has also significantly increased from 82 (model_5) to 96.

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Red' > **Model Selection (Final Model):**
# <br> <left> <font size=3 style='font-family:Courier New' color='Black'> By comparing the 6 models, we might find that both **model_3**, **model_4**, and **model_5** have similar Performance Metrics in terms of Loss, Recall and FN:
# <br> <left> <font size=3 style='font-family:Courier New' color='Black'> **model_3:**
# <br> <left> <font size=3 style='font-family:Courier New' color='Blue'> Recall Value = 0.755.
# <br> <left> <font size=3 style='font-family:Courier New' color='Blue'> False Negatives (FN) = 80.
# <br> <left> <font size=3 style='font-family:Courier New' color='Blue'> No. of Epochs = 13.
# <br> <left> <font size=3 style='font-family:Courier New' color='Blue'> Loss Curve = Medium Noise, Large Gap.
#
# <br> <left> <font size=3 style='font-family:Courier New' color='Black'> **model_4:**
# <br> <left> <font size=3 style='font-family:Courier New' color='Blue'> Recall Value = 0.739.
# <br> <left> <font size=3 style='font-family:Courier New' color='Blue'> False Negatives (FN) = 85.
# <br> <left> <font size=3 style='font-family:Courier New' color='Blue'> No. of Epochs = 24.
# <br> <left> <font size=3 style='font-family:Courier New' color='Blue'> Loss Curve = Low Noise, Medium Gap.
#
# <br> <left> <font size=3 style='font-family:Courier New' color='Black'> **model_5:**
# <br> <left> <font size=3 style='font-family:Courier New' color='Blue'> Recall Value = 0.748.
# <br> <left> <font size=3 style='font-family:Courier New' color='Blue'> False Negatives (FN) = 82.
# <br> <left> <font size=3 style='font-family:Courier New' color='Blue'> No. of Epochs = 13.
# <br> <left> <font size=3 style='font-family:Courier New' color='Blue'> Loss Curve = High Noise, Small Gap.
#
# <br> <left> <font size=3 style='font-family:Courier New' color='Black'> Although model_3 has slightly higher Recall and lower FN than both model_4 and model_5, model_4 shows the best stable Validation curve among all models. Furthermore, model_4 has been exposed to Training Data Points (24 Epochs) more than other models.
# <br> <left> <font size=3 style='font-family:Courier New' color='Black'> Finally, we would propose <font color='Red' > **model_4** <font color='Black' > as the Optimum/Best Model.
#
# <br> <left> <font size=3 style='font-family:Courier New' color='Black'> **Note**
# <br> <left> <font size=3 style='font-family:Courier New' color='Black'> **1.** The performance of all models on Testing Subset has been already verified and the results were as follow:
# <br> <left> <font size=3 style='font-family:Courier New' color='Black'> **-** Model_3: FN = 109.
# <br> <left> <font size=3 style='font-family:Courier New' color='Black'> **-** Model_4: FN = 103.
# <br> <left> <font size=3 style='font-family:Courier New' color='Black'> **-** Model_5: FN = 114.
# <br> <left> <font size=3 style='font-family:Courier New' color='Black'> **2.** Further steps (Out of Project Scope) could be taken to improve the Model's Performance like kernel_initialize, kernel_regularizer, and Batch Normalization.

# %%
# Finding the Predictions of best model using model_4 Parameters:

print('\033[0m' , '\033[92m' , 'Threshold (' ,
      '\033[1m' , '\033[91m' , 'model_4' ,
      '\033[0m' , '\033[92m' , ') = '
      '\033[0m' , '\033[92m' , threshold_4 , sep='')

y_result = model_4.predict(X_test)
y_result_test = (y_result > threshold_4)
# Out:
# Threshold (model_4) = 0.15963462

# %%
# Displaying the Classification Report of best model:

print(classification_report(y_test , y_result_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.80      0.86      1593
#            1       0.49      0.75      0.59       407
#
#     accuracy                           0.79      2000
#    macro avg       0.71      0.77      0.72      2000
# weighted avg       0.84      0.79      0.80      2000

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** The gap of Recall values between Classes is similar to the gap obtained using model_3 (0.5).

# %%
# Plotting the Confusion Matrix of best model:

cm = confusion_matrix(y_test , y_result_test)
labels = ['True Negative' , 'False Positive' , 'False Negative' , 'True Positive']
categories = ['Not Exited' , 'Exited']
plot_confusion_matrix(cm , group_names=labels , categories=categories , cmap='viridis')
# Out:
# Accuracy = 0.788
# Precision = 0.486
# Recall = 0.747
# F1 Score = 0.589

# %% [markdown]
# <left> <font size=5 style='font-family:Courier New' color='Grey'> **Observations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** Recall value is higher then its value on Validation Subset of model_4 (0.739). Such observation eliminate the possibility of Over-Fitting.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2.** FN has increased from 85 (Validation) to 103 (Testing). Such observation indicates the below possibilities:
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **-** Dataset does not contain clear and strong pattern of relationships.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **-** More Data Points are required to gain stronger learning mechanism.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **-** Extra Techniques (like Optimization, Dropout, Normalizations, etc) are still required to find the optimum Neural Network Model that gives the highest accuracy.

# %% [markdown]
# <left> <font size=6 style='font-family:Courier New' color='Orange' > **7. Business Recommendations:**
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **1.** At the beginning, it's worthy to guide the business owner into the most important factors that influence his customers decision to either stay or leave:
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **-** Customers who have lower credit score tend to leave the bank more those who have higher credit score.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **-** Customers who live in Germany tend to leave the bank more than those who live in France or Spain.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **-** Female customers tend to leave the bank more than male customers.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **-** Older customers tend to leave the bank more than younger customers.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **-** Tenure has no effect on customers decision.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **-** Customers who have higher balance tend to leave the bank more than those who have lower balance.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **-** Customers who have more products tend to leave the bank more than those who have less products.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **-** Holding a credit card has no effect on customers decision.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **-** Active customers tend to leave the bank more than inactive customers.
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **-** Estimated salary has no effect on customers decision.
#
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **2.** Bank's management must give high priority in dealing with bank's Declining performance in Germany, it's quite scary to imagine that one third of bank's base of customers in Germany has been lost within the past six months!
#
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **3.** Further to above point, German customers have the higher average balance among all customers. As a result, maintaining them as well as attract others would be fruitful to increase the Bank's assets.
#
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **4.** Bank's management must review its contact channels deeply, having a diverse base of customers from different countries speaking different languages require strong capabilities to achieve desired outputs.
#
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **5.** Although the distribution/coverage of bank branches is not included in the study, we highly recommend the bank's management to restudy such distribution to exclude the probability of Churn due to the absence/shortage of branches in the cities where Customers are most likely to exit.
#
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **6.** Bank's management must do its best endeavours to investigate the reason behind leaving female customers. A quarter of females have already left the bank in the last six months constitutes a huge challenge and must be stopped and compensated by reattracting them back or acquiring new ones.
#
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **7.** Further to above point, conducting a survey to understand the female customers opinions and needs may help the bank's management to establish more suitable and sustainable services in a manner that ensure the loyalty of this important segment, as well as to enlarge it by adding more of such customers.
#
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **8.** Although all customers whatever their age are important and constitute together the bank's assets and strength, older customers - sometimes - represent the segment of people with higher salaries, positions, and larger family size. Consequently, paying more attention to such segment will be great and meaningful.
#
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **9.** Having sufficient farsightedness would help in anticipating the future in different angle, customers holding higher positions interpreted to a decision makers who have the power to use the bank services to manage their enterprise accounts including loans, staff salaries, and business transactions. On the other hand, customers with large family size may use the same approach to have more individual accounts to their family members.
#
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **10.** Bank's management should pay extremely more attention to investigate the leaving behaviour within customers who have higher balance and work accordingly to remedy such risky behaviou effectively and quickly. Furthermore, no need to say that such VIP/rich customers are the most favoured and most vulnerable to attraction campaigns by all competitors.
#
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **11.** It's all about talking to customers, understand their needs, and solving their snags in a way they feel comfort and valuable. Additionally, Bank must be creative and proactive in initiating attractive products, launching promotional/advertising materials, use the latest technologies, as well as consciously improving its staff capabilities and courtesies.
#
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **12.** Field Study to explore the services that are being provided by competitors would be very helpful and enable the bank's management to easily compare the bank services with others and find out the market benchmark. Management may be able to outline the deficiencies in bank services and products that led to such churn behaviour.
#
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **13.** Knowing that higher No. of Products have a negative impact on maintaining the Customers loyalty, might refer to difficulties in managing such products by customers. i.e.: It may happen that similar products require different ways to manage despite of such similarity.
#
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **14.** Further to above point, a specialized technical team can study the different products and suggest a simpler way to manage it by either reduce the required steps or even to combine as much possible of products into one go.
#
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **15.** Low fees products, loyalty programs, rewards, and discount's agreements with diverse base of service providers (retail stores, hotels, airlines, cars rental, etc) will have a great impact in increasing the Customers base as well as maintaining the loyalty of current one.
#
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **16.** Although customers with low Credit Score are most likely to default, it's still an important task to investigate the reason behind leaving of such segment (one third of customers with low credit score have left the bank within the last six months). Therefore, bank's management can find better ways to deal with such customers if the defaulting was the main behind churn; such ways are including but not limited to rescheduling their debts in a way does not affect the bank statements and profits.
#
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **17.** As a sustainable business's strategy, friendly customer care and easy to use banking services would have a Positive Return on Investment.
#
# <br> <left> <font size=3 style='font-family:Courier New' color='black'> **18.** Since the bank is operating in different countries, different cultures, lifestyles, and needs would be found. Therefore, understanding such factors will help in both understanding the operational environment more effectively and finding the best ways of attracting and growth.
